# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import time
from functools import partial

import polars as pl
from selenium.webdriver.common.by import By
from tqdm import tqdm

from prefect_perso.utils.selenium import (
    get_driver,
    get_element,
    get_elements,
    highlight_element,
)

repo_path = r"D:\projets_python_ssd\Sencrop\perso\MH_Wilds_tools"

# %%
driver = get_driver(headless=False)
# Out:
# d:\projets_python_ssd\perso\scheduled_tasks\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:1020: UserWarning: Only 'current' window is supported for W3C compatible browsers.
#   self._check_if_window_handle_is_current(windowHandle)
# 10:29:26.047 | INFO    | Task run 'get_driver' - Finished in state Completed()

# %% [markdown]
# # Scrape all quests rewards

# %%
quest_page = "https://mhwilds.kiranico.com/fr/data/missions"

driver.get(quest_page)

# %%
quest_scroll_element = get_element(driver, (By.CLASS_NAME, "my-8"))
quests = get_elements(quest_scroll_element, (By.CLASS_NAME, "transition-colors"))

all_quests = []

for quest in quests:
    quest_name = quest.find_elements(By.TAG_NAME, "td")[0]
    quest_name = quest_name.find_element(By.TAG_NAME, "a")

    all_quests.append(
        {
            "name": quest_name.text,
            "href": quest_name.get_attribute("href"),
        }
    )
# all_quests

# %%
for quest in tqdm(all_quests):
    href = quest["href"]
    driver.get(href)
    quest["rewards"] = {}

    recompenses_element = driver.find_element(
        By.XPATH,
        "//h3[contains(text(), 'Récompenses')]",
    )
    parent_element = recompenses_element.find_element(By.XPATH, "..")

    # Get all rewards
    recompenses_list = []
    recompenses = parent_element.find_elements(By.TAG_NAME, "tr")
    for recompense in recompenses:
        value = recompense.find_elements(By.TAG_NAME, "td")[0]
        item = value.find_element(By.TAG_NAME, "a").text
        quantity = value.text.replace(item, "").strip().replace("x", "")
        match quantity:
            case "":
                quantity = 1
            case _:
                quantity = int(quantity)
        recompenses_list.append({"item": item, "quantity": quantity})
    quest["rewards"] = recompenses_list

# quest
# Out:
# 100%|██████████| 81/81 [00:35<00:00,  2.29it/s]

# %%
(
    pl.DataFrame(all_quests)
    #
    .explode("rewards")
    .with_columns(
        pl.col("rewards").struct.field("item").alias("item"),
        pl.col("rewards").struct.field("quantity").alias("quantity"),
    )
    .drop("rewards")
    .filter(pl.col("item").is_not_null())
    .sort("item", "quantity", descending=[False, True])
    .to_pandas()
    .get(["name", "item", "quantity"])
    .to_parquet(os.path.join(repo_path, "data", "quests.parquet"))
)

# %%
print(
    pl.DataFrame(all_quests)
    #
    .explode("rewards")
    .with_columns(
        pl.col("rewards").struct.field("item").alias("item"),
        pl.col("rewards").struct.field("quantity").alias("quantity"),
    )
    .drop("rewards")
    .filter(pl.col("item").is_not_null())
    .sort("item", "quantity", descending=[False, True])
    .to_pandas()
    .get(["name", "item", "quantity"])
    .to_markdown(index=False)
)
# Out:
# | name                                     | item                         |   quantity |
# |:-----------------------------------------|:-----------------------------|-----------:|
# | Les fidèles Veilleurs                    | Ail de Sild                  |          3 |
# | Lutte pour la survie                     | Ail de Sild spécial          |          3 |
# | Capacité d'adaptation                    | Ail de Sild spécial          |          1 |
# | Doshaguma sylvestre                      | Bombe tranquillisante        |         20 |
# | Un visiteur venu de l'Ouest              | Bombe tranquillisante        |         10 |
# | Nouveaux écosystèmes                     | Bombe tranquillisante        |         10 |
# | Le village où chante le vent             | Bouillon d'amerinsecte       |          5 |
# | Et la lumière fut                        | Capsule aveuglante           |         10 |
# | Attention au Gypceros                    | Carbalite                    |          3 |
# | Exploration sylvestre                    | Champibave                   |          3 |
# | Abîmation de fourrure, très mauvais poil | Champidélice                 |          3 |
# | Une transaction au poil                  | Champidélice                 |          1 |
# | Rapport de recherche de Samin            | Champignon bleu              |         10 |
# | Le prestige des chasseurs                | Champinitro                  |          5 |
# | Sentinelle                               | Chili monstre                |          3 |
# | Conflit incessant                        | Condensateur de foudrinsecte |         20 |
# | Délicieux débris                         | Crevette de boue             |          5 |
# | Flamme des temps anciens                 | Crevette de boue             |          3 |
# | Vers des terres ardentes                 | Crevette de boue             |          1 |
# | Fauteurs de troubles                     | Crevette turbide             |          3 |
# | Les angoisses d'Aida                     | Crevette turbide             |          1 |
# | Un éternel recommencement                | Cristal de lumière           |          1 |
# | Le village où chante le vent             | Cristal de terre             |          3 |
# | Un monde en furie                        | Cristal nova                 |          1 |
# | Torrent d'énergie                        | Cristal nova                 |          1 |
# | L'origine du mal                         | Cristal nova                 |          1 |
# | Vers des terres ardentes                 | Dragonite                    |          5 |
# | Les fidèles Veilleurs                    | Essence d'insecte immortel   |         10 |
# | Vers le Sanctuaire des wyvernes          | Extrait d'arginine           |          5 |
# | La wyverne et la rose                    | Extrait d'arginine           |          5 |
# | Le grand méchant loot                    | Extrait d'arginine           |          5 |
# | Un éternel recommencement                | Extrait d'arginine           |          3 |
# | Rapport de recherche spécial de Dareel   | Fleur du crépuscule          |         10 |
# | Fauteurs de troubles                     | Fléau du diable              |         10 |
# | La wyverne et la rose                    | Fragment d'arme abîmé        |          3 |
# | Vers le Sanctuaire des wyvernes          | Fragment d'arme abîmé        |          3 |
# | L'œil du cyclone                         | Fromage de Kunafa            |          3 |
# | Le prestige des chasseurs                | Fromage de Kunafa            |          3 |
# | Le village où chante le vent             | Fromage de Kunafa            |          1 |
# | Conflit incessant                        | Fromage de Kunafa fort       |          3 |
# | Attention au Gypceros                    | Fromage de Kunafa fort       |          1 |
# | Rage du léviathan                        | Fromage de Kunafa fort       |          1 |
# | Rêves de retour                          | Glacios gelé                 |          3 |
# | Aberrante atrocité                       | Gracium                      |          2 |
# | Rapport de recherche de Dareel (suite)   | Graine de force              |         10 |
# | L'œil du cyclone                         | Graine de ténacité           |         10 |
# | Rath-des-cieux, en avant !               | Grande bombe baril           |         10 |
# | Doshaguma sylvestre                      | Grande capsule de bouse      |         10 |
# | Rapport de recherche spécial de Samin    | Herbe sauvage                |          5 |
# | Un visiteur venu de l'Ouest              | Herbe sauvage                |          3 |
# | Nouveaux écosystèmes                     | Herbe sauvage                |          3 |
# | Sécuriser le Vallon meurtri              | Huile de graines sauvages    |          3 |
# | Rêves de retour                          | Icium                        |          3 |
# | Le prestige des chasseurs                | Machalite                    |          3 |
# | Rapport de recherche de Samin (suite)    | Mandragore                   |         10 |
# | Abîmation de fourrure, très mauvais poil | Miel                         |         30 |
# | Rapport de recherche spécial de Samin    | Miel                         |         10 |
# | Rapport de recherche de Dareel           | Miel                         |         10 |
# | Rapport de recherche de Dareel (suite)   | Miel                         |          5 |
# | La prise du siècle !                     | Miel                         |          5 |
# | Pêche savoureuse                         | Miel                         |          5 |
# | Rapport de recherche de Samin            | Miel                         |          5 |
# | À la recherche du poisson d'or           | Miel                         |          5 |
# | La pêche, c'est la vie                   | Miel                         |          5 |
# | Rapport de recherche de Samin (suite)    | Miel                         |          5 |
# | Rapport de recherche spécial de Dareel   | Miel                         |          5 |
# | Rage du léviathan                        | Miel oriental                |          5 |
# | L'expérience de Werner                   | Méga bombe baril             |         10 |
# | Un monde en furie                        | Méga potion                  |         30 |
# | Torrent d'énergie                        | Méga potion                  |         30 |
# | L'origine du mal                         | Méga potion                  |         30 |
# | Vers le Sanctuaire des wyvernes          | Méga potion                  |         20 |
# | Chaînes brisées                          | Méga potion                  |         20 |
# | La wyverne et la rose                    | Méga potion                  |         20 |
# | Aide à la guérison                       | Méga potion                  |         10 |
# | Au-delà du déluge                        | Méga potion                  |         10 |
# | Flamme des temps anciens                 | Méga potion                  |         10 |
# | Rester de glace                          | Méga potion                  |         10 |
# | À la recherche du poisson d'or           | Nageoire de poissaiguiseur   |          3 |
# | Plein les mirettes !                     | Nageoire de poissaiguiseur   |          2 |
# | Les fidèles Veilleurs                    | Os Gardien solide            |          3 |
# | Les angoisses d'Aida                     | Os de qualité                |          5 |
# | Exploration sylvestre                    | Os solide                    |          3 |
# | Voyage dans le désert                    | Peau Chatacabra              |          3 |
# | Flamme des temps anciens                 | Pierre de feu                |          1 |
# | Délicieux débris                         | Pierre de lave               |          1 |
# | Ce que nous protégeons                   | Pièce wyverne antique        |         10 |
# | Aberrante atrocité                       | Pièce wyverne antique        |          5 |
# | Gage de qualité de la Forge              | Piège à fosse                |         10 |
# | Gage de qualité de la Forge              | Piège électrochoc            |         10 |
# | Un visiteur venu de l'Ouest              | Piège électrochoc            |          5 |
# | Nouveaux écosystèmes                     | Piège électrochoc            |          5 |
# | Écho dans les Falaises                   | Potion ancestrale            |          5 |
# | Une entreprise risquée                   | Potion ancestrale            |          3 |
# | Sentinelle                               | Potion de pierre +           |          5 |
# | Une entreprise risquée                   | Potion secrète               |          5 |
# | Voyage dans le désert                    | Potion secrète               |          3 |
# | Chaînes brisées                          | Potion secrète               |          3 |
# | Rester de glace                          | Potion secrète               |          3 |
# | Sécuriser le Vallon meurtri              | Poudre de pierre             |          5 |
# | Rendez-vous                              | Poudre de vie                |         30 |
# | Une ombre menaçante                      | Poudre de vie                |         30 |
# | Voyage dans le désert                    | Poudre de vie                |          5 |
# | Voyage dans le désert                    | Poudre de vie                |          5 |
# | Exploration sylvestre                    | Poudre de vie                |          5 |
# | Un éternel recommencement                | Poudre de vie                |          5 |
# | L'expérience de Werner                   | Poudre du démon              |          5 |
# | Lutte pour la survie                     | Poussière de vie             |         10 |
# | Présages                                 | Poussière de vie             |         10 |
# | Déluge de glace                          | Poussière de vie             |         10 |
# | Capacité d'adaptation                    | Poussière de vie             |         10 |
# | Une ombre menaçante                      | Poussière de vie             |          5 |
# | Rendez-vous                              | Poussière de vie             |          5 |
# | Plein les mirettes !                     | Poutargue brillante          |          5 |
# | Pêche savoureuse                         | Poutargue brillante          |          3 |
# | L'origine du mal                         | Relique de dragon            |          1 |
# | Torrent d'énergie                        | Relique de dragon            |          1 |
# | Un monde en furie                        | Relique de dragon            |          1 |
# | Au-delà du déluge                        | Remède d'herbe               |          5 |
# | Rêves de retour                          | Sphère d'armure              |         10 |
# | Vers des terres ardentes                 | Sphère d'armure              |          5 |
# | Rester de glace                          | Sphère d'armure +            |          5 |
# | Sécuriser le Vallon meurtri              | Sphère d'armure acérée       |          8 |
# | Matériaux de qualité                     | Sphère d'armure acérée       |          5 |
# | Déluge de glace                          | Sphère d'armure dense        |          5 |
# | Présages                                 | Sphère d'armure dense        |          5 |
# | Sentinelle                               | Sphère d'armure dense        |          3 |
# | Une transaction au poil                  | Truffe du Conga              |          3 |
# | Ce que nous protégeons                   | Urne grande écaille-or       |          1 |
# | L'œil du cyclone                         | Viande crue                  |         10 |
# | La prise du siècle !                     | Écaille de poisson-poudre    |          5 |
# | Plein les mirettes !                     | Écaille de poisson-poudre    |          3 |
# | Plein les mirettes !                     | Écaille de sushipoisson      |          5 |
# | La pêche, c'est la vie                   | Écaille de sushipoisson      |          5 |
# | Une ombre menaçante                      | Éclat de furie               |          3 |
# | Rendez-vous                              | Éclat de furie               |          3 |
# | Écho dans les Falaises                   | Œuf léger                    |          3 |
# | Chaînes brisées                          | Œuf soyeux                   |          3 |

# %% [markdown]
# # Scrape armors

# %%
armor_href = "https://mhwilds.kiranico.com/fr/data/armor-series"
driver.get(armor_href)

# %%
sets_scroll = get_element(driver, (By.CLASS_NAME, "my-8"))
set_hrefs = [
    _.get_attribute("href") for _ in get_elements(sets_scroll, (By.TAG_NAME, "a"))
]

# %% [markdown]
# ### Set talents

# %%
all_pieces = []
for set_href in tqdm(set_hrefs):
    driver.get(set_href)
    # Parse set data
    set_name = get_element(driver, (By.TAG_NAME, "h2")).text
    talent_table = (
        driver.find_element(
            By.XPATH,
            '//th[contains(text(), "Talents de l\'équipement")]',
        )
        .find_element(By.XPATH, "..")
        .find_element(By.XPATH, "..")
    )

    talent_table_rows = talent_table.find_elements(By.TAG_NAME, "tr")[1:]
    for talent_table_row in talent_table_rows:
        piece, name, jewels, talent = talent_table_row.find_elements(By.TAG_NAME, "td")
        piece = piece.text
        name = name.text
        jewels = jewels.text

        # Extract jewel levels
        all_jewels = {"0": 0, "1": 0, "2": 0, "3": 0, "4": 0}
        for char in jewels.replace("[", "").replace("]", ""):
            all_jewels[char] += 1

        # Extract talents
        all_talents = []
        try:
            talents = talent.find_elements(By.TAG_NAME, "a")
        except:
            continue
        for _talent in talents:
            talent_href = _talent.get_attribute("href")
            talent_name = _talent.text
            talent_level = int(talent_name.split("+")[-1])
            talent_name = talent_name.split("+")[:-1]
            talent_name = "+".join(talent_name).strip()
            all_talents.append(
                {
                    "talent_name": talent_name,
                    "talent_level": talent_level,
                }
            )
        piece_dict = {
            "piece": piece,
            "name": name,
            "jewels": all_jewels,
            "talents": all_talents,
        }
        all_pieces.append(piece_dict)

all_pieces
# Out:
# 100%|██████████| 132/132 [01:13<00:00,  1.80it/s]
# [{'piece': 'Tête',
#   'name': "Masque d'espoir",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': "Cotte d'espoir",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': "Avant-bras d'espoir",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': "Tassette d'espoir",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': "Grèves d'espoir",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Lunettes en cuir',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Tunique en cuir',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Gants en cuir',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Coupe-faim', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Ceinture en cuir',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Pantalon en cuir',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume de mailles',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Veste de mailles',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Gants de mailles',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Ceinture de mailles',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Pantalon de mailles',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': "Heaume d'os",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': "Cotte d'os",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': "Avant-bras d'os",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': "Tassette d'os",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': "Grèves d'os",
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Lunettes Bulaqchi',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Entomologiste', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Talioth',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Saut de la foi', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Chatacabra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Veste Chatacabra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Chatacabra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Boucle Chatacabra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Chatacabra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Quematrice',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Quematrice',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Ignifuge', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Quematrice',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Quematrice',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Ignifuge', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Quematrice',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume en alliage',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte en alliage',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Sismologie', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras alliage',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Sismologie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Boucle en alliage',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Sismologie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves en alliage',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Piragill',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Étanchéité', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Vespoid',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Vespoid',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Vespoid',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Vespoid',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Vespoid',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Bottes Gajau',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Étanchéité', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Coiffe Lala Barina',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Lala Barina',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Lala Barina',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Lala Barina',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Lala Barina',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Congalala',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Mycologue extrême', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Congalala',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Mycologue extrême', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Congalala',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Antipuanteur', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Congalala',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Antipuanteur', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Congalala',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Mycologue extrême', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Balahara',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Coupe-faim', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Balahara',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Balahara',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Trompe-la-mort', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Balahara',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Trompe-la-mort', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Balahara',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Trompe-la-mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Doshaguma',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Pique-assiette', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Doshaguma',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Pique-assiette', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Doshaguma',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Doshaguma',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Doshaguma',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Pique-assiette', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume en lingot',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte en lingot',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pare-vent', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras en lingot',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette en lingot',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves en lingot',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pare-vent', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Plastron Kranodath',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Accessoire Comaqchi',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Insomnie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Masque Rompopolo',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Rompopolo',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Rompopolo',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1},
#    {'talent_name': 'Toxicologie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Rompopolo',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1},
#    {'talent_name': 'Toxicologie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Rompopolo',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Nerscylla',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Nerscylla',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Anti-immobilisation', 'talent_level': 1},
#    {'talent_name': 'Toxicologie', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Nerscylla',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Nerscylla',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Anti-immobilisation', 'talent_level': 1},
#    {'talent_name': 'Insomnie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Nerscylla',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Coiffe Hirabami',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Hirabami',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Hirabami',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Antigel', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Hirabami',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Antigel', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Hirabami',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Antigel', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Ajarakan',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Destructeur', 'talent_level': 1},
#    {'talent_name': 'Bombardier', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Ajarakan',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Destructeur', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Ajarakan',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Bombardier', 'talent_level': 1},
#    {'talent_name': "Monte-en-l'air", 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Ajarakan',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Bombardier', 'talent_level': 1},
#    {'talent_name': 'Antiexplosion', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Ajarakan',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Destructeur', 'talent_level': 1},
#    {'talent_name': 'Antiexplosion', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Seikret Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Acrobate', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Uth Duna',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Couverture de l'Uth Duna", 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Expert en survie', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Uth Duna',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Couverture de l'Uth Duna", 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Performance optimale', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Uth Duna',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Couverture de l'Uth Duna", 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Expert en survie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Uth Duna',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Couverture de l'Uth Duna", 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Expert en survie', 'talent_level': 1},
#    {'talent_name': 'Mobilité eau/boue huileuse', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Uth Duna',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Couverture de l'Uth Duna", 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Performance optimale', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Rey Dau',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tension du Rey Dau', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Force latente', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Rey Dau',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tension du Rey Dau', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Rey Dau',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tension du Rey Dau', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Force latente', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Rey Dau',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tension du Rey Dau', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Rey Dau',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tension du Rey Dau', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Force latente', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Nu Udra',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Nu Udra',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Nu Udra',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Nu Udra',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Nu Udra',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Doshaguma Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Héroïsme', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Doshaguma Gardien',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Héroïsme', 'talent_level': 1},
#    {'talent_name': 'Peau de fer', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Doshaguma Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Doshaguma Gardien',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Héroïsme', 'talent_level': 1},
#    {'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Doshaguma Gardien',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Puissance du Doshaguma', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Marathonien', 'talent_level': 1},
#    {'talent_name': 'Peau de fer', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Rathalos Gardien',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Éclat du Rathalos', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1},
#    {'talent_name': 'Intimidation', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Rathalos Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Éclat du Rathalos', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Intimidation', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Rathalos Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Éclat du Rathalos', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Rathalos Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Éclat du Rathalos', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Intimidation', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Rathalos Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Éclat du Rathalos', 'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume désastre G',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Pouvoir de l'Odogaron désastre",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte désastre G',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Pouvoir de l'Odogaron désastre",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Antihémorragie', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras désastre G',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Pouvoir de l'Odogaron désastre",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette désastre G',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Pouvoir de l'Odogaron désastre",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1},
#    {'talent_name': 'Antihémorragie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves désastre G',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Pouvoir de l'Odogaron désastre",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Antihémorragie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Xu Wu',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Corps et âme', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Xu Wu',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Métabolisme', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Xu Wu',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Corps et âme', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Xu Wu',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Corps et âme', 'talent_level': 1},
#    {'talent_name': 'Métabolisme', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Xu Wu',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Métabolisme', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Arkveld Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Arkveld Gardien',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Arkveld Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Arkveld Gardien',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Arkveld Gardien',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': "Masque d'espoir α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': "Cotte d'espoir α",
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Toxicologie', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': "Avant-bras d'espoir α",
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Insomnie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': "Tassette d'espoir α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Bénédiction', 'talent_level': 1},
#    {'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': "Grèves d'espoir α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Lunettes en cuir α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': 'Tunique en cuir α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Gants en cuir α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Botaniste', 'talent_level': 1},
#    {'talent_name': 'Coupe-faim', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Ceinture en cuir α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Coupe-faim', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Pantalon en cuir α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Coupe-faim', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume de mailles α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Veste de mailles α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1},
#    {'talent_name': 'Antigel', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Gants de mailles α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Géologiste', 'talent_level': 1},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Ceinture de mailles α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Halo de guérison', 'talent_level': 1},
#    {'talent_name': 'Antigel', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Pantalon de mailles α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': "Heaume d'os α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': "Cotte d'os α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1},
#    {'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': "Avant-bras d'os α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': "Tassette d'os α",
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Marathonien', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': "Grèves d'os α",
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Crâne d'acier", 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume en alliage α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte en alliage α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Nerfs d'acier", 'talent_level': 2}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras en alliage α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Sismologie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Boucle en alliage α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Sismologie', 'talent_level': 1},
#    {'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves en alliage α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Rengainage éclair', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Lunettes Bulaqchi α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Entomologiste', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Lunettes Bulaqchi β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Entomologiste', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Talioth α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Saut de la foi', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Talioth β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Douceur du cuir', 'talent_level': 1},
#    {'talent_name': 'Saut de la foi', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Piragill α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Mobilité eau/boue huileuse', 'talent_level': 1},
#    {'talent_name': 'Étanchéité', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Piragill β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Douceur du cuir', 'talent_level': 1},
#    {'talent_name': 'Mobilité eau/boue huileuse', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Vespoid α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Vespoid α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Vespoid α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Vespoid α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Vespoid α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Vespoid β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Vespoid β',
#   'jewels': {'0': 0, '1': 3, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Vespoid β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Vespoid β',
#   'jewels': {'0': 0, '1': 3, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Antiparalysie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Vespoid β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Ami de la nature', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Plastron Kranodath α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 2},
#    {'talent_name': 'Destructeur', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Plastron Kranodath β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Accessoire Comaqchi α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Alerte Neopteron', 'talent_level': 1},
#    {'talent_name': 'Insomnie', 'talent_level': 2},
#    {'talent_name': 'Incursion', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Accessoire Comaqchi β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Camouflage Neopteron', 'talent_level': 1},
#    {'talent_name': 'Insomnie', 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Kut-Ku α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2},
#    {'talent_name': 'Ignifuge', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Kut-Ku α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Témérité', 'talent_level': 1},
#    {'talent_name': 'Ignifuge', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Kut-Ku α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1},
#    {'talent_name': 'Témérité', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Kut-Ku α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Témérité', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Kut-Ku α',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Kut-Ku β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Kut-Ku β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Témérité', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Kut-Ku β',
#   'jewels': {'0': 0, '1': 2, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Kut-Ku β',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Témérité', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Kut-Ku β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1},
#    {'talent_name': 'Cercle de vie', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Chatacabra α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Veste Chatacabra α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Chatacabra α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1},
#    {'talent_name': 'Un pour tous', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Boucle Chatacabra α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Chatacabra α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Cuir souple', 'talent_level': 1},
#    {'talent_name': 'Chimiste', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Chatacabra β',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Douceur du cuir', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Veste Chatacabra β',
#   'jewels': {'0': 0, '1': 3, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Douceur du cuir', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Chatacabra β',
# ...
#    {'talent_name': 'Vengeance', 'talent_level': 2},
#    {'talent_name': 'Contre-attaque', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Nu Udra α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Nu Udra α',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 2},
#    {'talent_name': 'Contre-attaque', 'talent_level': 2}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Nu Udra α',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 2},
#    {'talent_name': 'Carnassier', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Nu Udra α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Faveur du seigneur', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1},
#    {'talent_name': 'Pare-vent', 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Nu Udra β',
#   'jewels': {'0': 1, '1': 0, '2': 2, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Rage supérieure', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1},
#    {'talent_name': 'Contre-attaque', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Nu Udra β',
#   'jewels': {'0': 0, '1': 2, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Rage supérieure', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Nu Udra β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Rage supérieure', 'talent_level': 1},
#    {'talent_name': 'Carnassier', 'talent_level': 2},
#    {'talent_name': 'Contre-attaque', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Nu Udra β',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Rage supérieure', 'talent_level': 1},
#    {'talent_name': 'Vengeance', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Nu Udra β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Mutinerie du Nu Udra', 'talent_level': 1},
#    {'talent_name': 'Rage supérieure', 'talent_level': 1},
#    {'talent_name': 'Vendetta', 'talent_level': 1},
#    {'talent_name': 'Pare-vent', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Gore Magala α',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 2},
#    {'talent_name': 'Union', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Gore Magala α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 2},
#    {'talent_name': 'Antivirus', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Gore Magala α',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2}]},
#  {'piece': 'Taille',
#   'name': 'Braconnière Gore Magala α',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2},
#    {'talent_name': 'Antivirus', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Gore Magala α',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Maîtrise des écailles', 'talent_level': 1},
#    {'talent_name': 'Antivirus', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Gore Magala β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Union', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Gore Magala β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 2}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Gore Magala β',
#   'jewels': {'0': 1, '1': 0, '2': 2, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': "Fenêtre d'invulnérabilité", 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Braconnière Gore Magala β',
#   'jewels': {'0': 1, '1': 0, '2': 1, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Gore Magala β',
#   'jewels': {'0': 0, '1': 2, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Tyrannie du Gore Magala', 'talent_level': 1},
#    {'talent_name': 'Écailles superposées', 'talent_level': 1},
#    {'talent_name': 'Antivirus', 'talent_level': 1},
#    {'talent_name': "Nerfs d'acier", 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Arkvulcan α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1},
#    {'talent_name': 'Absorption élémentaire', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Arkvulcan α',
#   'jewels': {'0': 2, '1': 0, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1},
#    {'talent_name': 'Absorption élémentaire', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Arkvulcan α',
#   'jewels': {'0': 1, '1': 0, '2': 2, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Arkvulcan α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 2},
#    {'talent_name': 'Halo de guérison', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Arkvulcan α',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1},
#    {'talent_name': 'Rengainage éclair', 'talent_level': 2}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Arkvulcan β',
#   'jewels': {'0': 0, '1': 1, '2': 1, '3': 1, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage attrayant', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Arkvulcan β',
#   'jewels': {'0': 1, '1': 0, '2': 1, '3': 1, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage attrayant', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Arkvulcan β',
#   'jewels': {'0': 0, '1': 1, '2': 2, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage attrayant', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Arkvulcan β',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage attrayant', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 2},
#    {'talent_name': 'Halo de guérison', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Arkvulcan β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': "Appétit de l'Arkveld", 'talent_level': 1},
#    {'talent_name': 'Pelage attrayant', 'talent_level': 1},
#    {'talent_name': 'Conversion élémentaire', 'talent_level': 1},
#    {'talent_name': 'Rengainage éclair', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Arkveld Gardien α',
#   'jewels': {'0': 1, '1': 2, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1},
#    {'talent_name': 'Destructeur', 'talent_level': 2}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Arkveld Gardien α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 2},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 2}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Arkveld Gardien α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 2},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Arkveld Gardien α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 2},
#    {'talent_name': 'Absorption élémentaire', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Arkveld Gardien α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Pouls du Gardien', 'talent_level': 1},
#    {'talent_name': 'Absorption élémentaire', 'talent_level': 2},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Heaume Arkveld Gardien β',
#   'jewels': {'0': 1, '1': 1, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Protection du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1},
#    {'talent_name': 'Destructeur', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte Arkveld Gardien β',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Protection du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 1},
#    {'talent_name': 'Totem élémentaire', 'talent_level': 2}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras Arkveld Gardien β',
#   'jewels': {'0': 0, '1': 3, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Protection du Gardien', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 2}]},
#  {'piece': 'Taille',
#   'name': 'Tassette Arkveld Gardien β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Protection du Gardien', 'talent_level': 1},
#    {'talent_name': 'Écorcheur', 'talent_level': 2}]},
#  {'piece': 'Jambes',
#   'name': 'Grèves Arkveld Gardien β',
#   'jewels': {'0': 1, '1': 1, '2': 1, '3': 0, '4': 0},
#   'talents': [{'talent_name': "Vitalité de l'Arkveld Gardien",
#     'talent_level': 1},
#    {'talent_name': 'Protection du Gardien', 'talent_level': 1},
#    {'talent_name': 'Absorption élémentaire', 'talent_level': 1},
#    {'talent_name': 'Mise à mort', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Boucles As de la Guilde α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Incursion', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Torse',
#   'name': 'Cotte As de la Guilde α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Incursion', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Bras',
#   'name': 'Avant-bras As de la Guilde α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Incursion', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Taille',
#   'name': 'Tassette As de la Guilde α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Incursion', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Jambes',
#   'name': 'Bottes As de la Guilde α',
#   'jewels': {'0': 2, '1': 0, '2': 0, '3': 1, '4': 0},
#   'talents': [{'talent_name': 'Performance optimale', 'talent_level': 1},
#    {'talent_name': 'Incursion', 'talent_level': 1},
#    {'talent_name': 'Athlète', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': 'Cache-œil Roi-dragon α',
#   'jewels': {'0': 3, '1': 0, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Contre-attaque', 'talent_level': 3}]},
#  {'piece': 'Tête',
#   'name': 'Mimiflore α',
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Pelage de renforcement', 'talent_level': 1},
#    {'talent_name': 'Entomologiste', 'talent_level': 1},
#    {'talent_name': 'Embuscade', 'talent_level': 1}]},
#  {'piece': 'Tête',
#   'name': "Heaume d'expédition α",
#   'jewels': {'0': 2, '1': 1, '2': 0, '3': 0, '4': 0},
#   'talents': [{'talent_name': 'Totem élémentaire', 'talent_level': 1},
#    {'talent_name': 'Union', 'talent_level': 1}]}]

# %%
armor_pieces = (
    pl.DataFrame(all_pieces)
    #
    .explode("talents")
    .with_columns(
        pl.col("talents").struct.field("talent_name").alias("talent_name"),
        pl.col("talents").struct.field("talent_level").alias("talent_level"),
    )
    .drop("talents")
    .with_columns(
        *[
            pl.col("jewels").struct.field(jwl_lvl).alias(f"jewel_{jwl_lvl}")
            for jwl_lvl in ["0", "1", "2", "3", "4"]
        ]
    )
    .drop("jewels")
)
armor_pieces.write_parquet(os.path.join(repo_path, "data", "armor_pieces.parquet"))
armor_pieces
# Out:
# shape: (1_488, 9)
# ┌────────┬───────────────┬──────────────┬──────────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ piece  ┆ name          ┆ talent_name  ┆ talent_level ┆ … ┆ jewel_1 ┆ jewel_2 ┆ jewel_3 ┆ jewel_4 │
# │ ---    ┆ ---           ┆ ---          ┆ ---          ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str    ┆ str           ┆ str          ┆ i64          ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════╪═══════════════╪══════════════╪══════════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ Tête   ┆ Masque        ┆ Crâne        ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'espoir      ┆ d'acier      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Torse  ┆ Cotte         ┆ Bénédiction  ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'espoir      ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Bras   ┆ Avant-bras    ┆ Bénédiction  ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'espoir      ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Taille ┆ Tassette      ┆ Crâne        ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'espoir      ┆ d'acier      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Jambes ┆ Grèves        ┆ Bénédiction  ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'espoir      ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# │ …      ┆ …             ┆ …            ┆ …            ┆ … ┆ …       ┆ …       ┆ …       ┆ …       │
# │ Tête   ┆ Mimiflore α   ┆ Pelage de    ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆               ┆ renforcement ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Tête   ┆ Mimiflore α   ┆ Entomologist ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆               ┆ e            ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Tête   ┆ Mimiflore α   ┆ Embuscade    ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │ Tête   ┆ Heaume        ┆ Totem        ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'expédition  ┆ élémentaire  ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ α             ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Tête   ┆ Heaume        ┆ Union        ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ d'expédition  ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ α             ┆              ┆              ┆   ┆         ┆         ┆         ┆         │
# └────────┴───────────────┴──────────────┴──────────────┴───┴─────────┴─────────┴─────────┴─────────┘

# %% [markdown]
# # Charms scraping

# %%
charms_url = "https://mhwilds.kiranico.com/fr/data/charms"
driver.get(charms_url)

# %%
charms_scroll = get_element(driver, (By.CLASS_NAME, "my-8"))
charms_elements = charms_scroll.find_elements(By.TAG_NAME, "tr")

all_charms = []
for charm_element in charms_elements:
    charm_element = charm_element.find_element(By.TAG_NAME, "a")
    charm_href = charm_element.get_attribute("href")
    charm_name = charm_element.text
    all_charms.append({"name": charm_name, "href": charm_href})
all_charms

# %%
for charm_element in tqdm(all_charms):
    href = charm_element["href"]
    driver.get(href)

    talent_table = get_element(driver, (By.TAG_NAME, "tbody"))
    talents = talent_table.find_elements(By.TAG_NAME, "tr")

    charm_talents = []
    for talent in talents:
        name, lvl, desc = talent.find_elements(By.TAG_NAME, "td")
        name = name.text
        lvl = int(lvl.text.replace("Lv", "").strip())
        charm_talents.append({"name": name, "lvl": lvl})
    charm_element["talents"] = charm_talents
# Out:
# 100%|██████████| 159/159 [00:49<00:00,  3.18it/s]

# %%
charms_data = (
    pl.DataFrame(all_charms)
    #
    .explode("talents")
    .with_columns(
        pl.col("talents").struct.field("name").alias("talent_name"),
        pl.col("talents").struct.field("lvl").alias("talent_lvl"),
    )
    .drop("talents")
    .sort("talent_name", "talent_lvl", descending=[False, True])
)
charms_data.write_parquet(os.path.join(repo_path, "data", "charms.parquet"))
charms_data
# Out:
# shape: (160, 4)
# ┌────────────────────────┬───────────────────────────────────┬────────────────────────┬────────────┐
# │ name                   ┆ href                              ┆ talent_name            ┆ talent_lvl │
# │ ---                    ┆ ---                               ┆ ---                    ┆ ---        │
# │ str                    ┆ str                               ┆ str                    ┆ i64        │
# ╞════════════════════════╪═══════════════════════════════════╪════════════════════════╪════════════╡
# │ Talisman d'absorption  ┆ https://mhwilds.kiranico.com/f…   ┆ Absorption élémentaire ┆ 1          │
# │ Talisman de survie III ┆ https://mhwilds.kiranico.com/f…   ┆ Ami de la nature       ┆ 3          │
# │ Talisman de survie II  ┆ https://mhwilds.kiranico.com/f…   ┆ Ami de la nature       ┆ 2          │
# │ Talisman de survie     ┆ https://mhwilds.kiranico.com/f…   ┆ Ami de la nature       ┆ 1          │
# │ Talisman               ┆ https://mhwilds.kiranico.com/f…   ┆ Anti-immobilisation    ┆ 3          │
# │ anti-immobilisation I… ┆                                   ┆                        ┆            │
# │ …                      ┆ …                                 ┆ …                      ┆ …          │
# │ Talisman d'incision II ┆ https://mhwilds.kiranico.com/f…   ┆ Écorcheur              ┆ 2          │
# │ Talisman d'incision    ┆ https://mhwilds.kiranico.com/f…   ┆ Écorcheur              ┆ 1          │
# │ Talisman d'eau III     ┆ https://mhwilds.kiranico.com/f…   ┆ Étanchéité             ┆ 3          │
# │ Talisman d'eau II      ┆ https://mhwilds.kiranico.com/f…   ┆ Étanchéité             ┆ 2          │
# │ Talisman d'eau         ┆ https://mhwilds.kiranico.com/f…   ┆ Étanchéité             ┆ 1          │
# └────────────────────────┴───────────────────────────────────┴────────────────────────┴────────────┘

# %% [markdown]
# # Scrap weapons

# %%
weapons_href = "https://mhwilds.kiranico.com/fr/data/weapons"
driver.get(weapons_href)

weapons_scroll = get_element(driver, (By.CLASS_NAME, "my-8"))

# %%
all_weapon_data = []

# Find the pagination bar for weapons
weapons_pagination_bar = weapons_scroll.find_element(By.XPATH, "//*[@dir='ltr']")
# Get all pagination buttons
weapons_pagination = weapons_pagination_bar.find_elements(By.TAG_NAME, "button")

# Determine the maximum number of pagination buttons
max_pagination = len(weapons_pagination)
# Iterate over pagination buttons in reverse order
for idx_pagination in tqdm(range(0, max_pagination)):
    pagination = weapons_pagination[list(range(0, max_pagination))[idx_pagination]]
    # Scroll to the top of the page
    driver.execute_script("window.scrollTo(0, 0);")
    # Click the pagination button
    pagination.click()
    time.sleep(2)

    # Get the weapon class from the pagination button
    weapon_class = pagination.get_attribute("aria-controls").split("-")[-1]
    # Find all weapon rows
    weapon_rows = weapons_scroll.find_elements(By.TAG_NAME, "tr")

    # Iterate over each weapon row
    for weapon_row in weapon_rows:
        img, name, jewels, raw, element, affinity, sharpness, extras, talents = (
            weapon_row.find_elements(By.TAG_NAME, "td")
        )

        # Extract image source
        img = img.find_element(By.TAG_NAME, "img").get_attribute("src")

        # Extract and clean weapon name
        name = name.text.strip()

        # Process jewels information
        jewels = (
            jewels.text.replace("③", "3")
            .replace("②", "2")
            .replace("①", "1")
            .replace("ー", "0")
            .strip()
        )
        jewels_list = {"0": 0, "1": 0, "2": 0, "3": 0}
        for jewel in jewels:
            jewels_list[jewel] += 1
        # Convert raw attack value to integer
        raw = int(raw.text.strip())

        try:
            # Attempt to extract element value and image source
            element_value = int(element.text.strip())
            element_img_href = element.find_element(By.TAG_NAME, "img").get_attribute(
                "src"
            )
        except:
            # Default values if extraction fails
            element_value = 0
            element_img_href = None

        try:
            # Attempt to extract affinity percentage
            affinity = int(affinity.text.replace("%", ""))
        except:
            # Default value if extraction fails
            affinity = 0

        try:
            # Attempt to extract sharpness SVGs
            sharpness_0, sharpness_1 = list(
                map(
                    lambda svg: driver.execute_script(
                        "return arguments[0].outerHTML;", svg
                    ),
                    sharpness.find_elements(By.TAG_NAME, "svg"),
                )
            )
            if not os.path.exists(os.path.join(repo_path, "data", "svg")):
                os.mkdir(os.path.join(repo_path, "data", "svg"))
            if not os.path.exists(os.path.join(repo_path, "data", "svg", weapon_class)):
                os.mkdir(os.path.join(repo_path, "data", "svg", weapon_class))

            with open(
                os.path.join(repo_path, "data", "svg", weapon_class, f"{name}_0.svg"),
                "w",
                encoding="utf-8",
            ) as f:
                f.write(sharpness_0)
            with open(
                os.path.join(repo_path, "data", "svg", weapon_class, f"{name}_1.svg"),
                "w",
                encoding="utf-8",
            ) as f:
                f.write(sharpness_1)
        except:
            pass

        # Find all talent elements
        talents_element_list = talents.find_elements(By.TAG_NAME, "a")

        talent_list = []
        # Iterate over each talent element
        for talent in talents_element_list:
            talent_href = talent.get_attribute("href")
            talent_text_raw = talent.text.strip()

            # Extract talent level and name
            talent_lvl = int(talent_text_raw.split("+")[-1])
            talent_name = "+".join(talent_text_raw.split("+")[:-1]).strip()
            talent_list.append(
                {
                    "name": talent_name,
                    "href": talent_href,
                    "lvl": talent_lvl,
                }
            )
        # Compile weapon data into a dictionary
        weapon_data = {
            "class": weapon_class,
            "img": img,
            "name": name,
            "jewels": jewels_list,
            "raw": raw,
            "element": {
                "value": element_value,
                "img_href": element_img_href,
            },
            "affinity": affinity,
            "talents": talent_list,
            "extra": extras.text.strip(),
        }
        # Append weapon data to the list
        all_weapon_data.append(weapon_data)
# Out:
# 100%|██████████| 14/14 [01:25<00:00,  6.09s/it]

# %%
(
    pl.DataFrame(all_weapon_data)
    #
    .write_parquet(os.path.join(repo_path, "data", "weapons.parquet"))
)

# %% [markdown]
# # Scrape jewels

# %%
jewels_href = "https://mhwilds.kiranico.com/fr/data/decorations"
driver.get(jewels_href)

# %%
jewels_scroll = get_element(driver, (By.CLASS_NAME, "my-8"))
jewels_elements = jewels_scroll.find_elements(By.TAG_NAME, "tr")

all_jewels = []

for jewel_element in jewels_elements:
    name, description = jewel_element.find_elements(By.TAG_NAME, "td")
    href = name.find_element(By.TAG_NAME, "a").get_attribute("href")

    all_jewels.append(
        {
            "name": name.text.strip(),
            "href": href,
            "description": description.text.strip(),
        }
    )
all_jewels

# %%
all_jewel_data = []
for jewel in tqdm(all_jewels):
    jewel_lvl = int(jewel["name"].split("[")[-1][0])
    driver.get(jewel["href"])
    talent_table = get_element(driver, (By.TAG_NAME, "tbody"))

    talent_list = talent_table.find_elements(By.TAG_NAME, "tr")

    jewel_talent_list = []
    for talent_element in talent_list:
        name, lvl, description = talent_element.find_elements(By.TAG_NAME, "td")
        href = name.find_element(By.TAG_NAME, "a").get_attribute("href")
        name = name.text.strip()
        lvl = int(lvl.text.replace("Lv", "").strip())
        description = description.text.strip()
        jewel_talent_list.append(
            {
                "name": name,
                "lvl": lvl,
                "description": description,
                "href": href,
            }
        )

    all_jewel_data.append(
        {
            "name": jewel["name"],
            "jewel_lvl": jewel_lvl,
            "jewel_talent_list": jewel_talent_list,
        }
    )
all_jewel_data
# Out:
# 100%|██████████| 361/361 [06:43<00:00,  1.12s/it]
# [{'name': 'Joyau attaque [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Machine de guerre',
#     'lvl': 1,
#     'description': "Augmente l'attaque.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre'}]},
#  {'name': 'Joyau attaque II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Machine de guerre',
#     'lvl': 2,
#     'description': "Augmente l'attaque.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre'}]},
#  {'name': 'Joyau attaque III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Machine de guerre',
#     'lvl': 3,
#     'description': "Augmente l'attaque.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre'}]},
#  {'name': 'Joyau vengeance [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Vengeance',
#     'lvl': 1,
#     'description': "Augmente l'attaque lorsque vous avez subi des dégâts temporaires (zone rouge de la jauge de vie).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/vengeance'}]},
#  {'name': 'Joyau riposte [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': "Poussée d'adrénaline",
#     'lvl': 1,
#     'description': "Esquivez juste avant une attaque pour un bonus d'attaque temporaire.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/poussee-dadrenaline'}]},
#  {'name': 'Joyau gardien [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau gardien II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 2,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau gardien III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau gardien/feu [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Pyromane',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'}]},
#  {'name': 'Joyau gardien/eau [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Maelstrom',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'}]},
#  {'name': 'Joyau gardien/glace [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Blizzard',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'}]},
#  {'name': 'Joyau gardien/foudre [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Feu du ciel',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'}]},
#  {'name': 'Joyau gardien/dracocide [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Pourfendeur de dragon',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'}]},
#  {'name': 'Joyau gardien/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau gardien/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Garde offensive',
#     'lvl': 3,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau parfait [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Performance optimale',
#     'lvl': 1,
#     'description': "Augmente l'attaque quand votre vie est à son maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/performance-optimale'}]},
#  {'name': 'Joyau contre-attaque [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Contre-attaque',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après avoir été projeté.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/contre-attaque'}]},
#  {'name': 'Joyau maître [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': "Maître d'armes",
#     'lvl': 1,
#     'description': "Augmente l'affinité.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes'}]},
#  {'name': 'Joyau maître II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': "Maître d'armes",
#     'lvl': 2,
#     'description': "Augmente l'affinité.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes'}]},
#  {'name': 'Joyau maître III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': "Maître d'armes",
#     'lvl': 3,
#     'description': "Augmente l'affinité.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes'}]},
#  {'name': 'Joyau berserk [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Berserker',
#     'lvl': 1,
#     'description': 'Augmente les dégâts des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/berserker'}]},
#  {'name': 'Joyau berserk II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Berserker',
#     'lvl': 2,
#     'description': 'Augmente les dégâts des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/berserker'}]},
#  {'name': 'Joyau berserk III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Berserker',
#     'lvl': 3,
#     'description': 'Augmente les dégâts des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/berserker'}]},
#  {'name': 'Joyau supplice [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Mise à mort',
#     'lvl': 1,
#     'description': "Augmente l'affinité lorsque vous attaquez le point faible d'un monstre et ses blessures.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/mise-a-mort'}]},
#  {'name': 'Joyau dégainage [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Dégainage éclair',
#     'lvl': 1,
#     'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair'}]},
#  {'name': 'Joyau dégainage II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Dégainage éclair',
#     'lvl': 2,
#     'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair'}]},
#  {'name': 'Joyau dégainage III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Dégainage éclair',
#     'lvl': 3,
#     'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair'}]},
#  {'name': 'Joyau omnipotence [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Corps et âme',
#     'lvl': 1,
#     'description': "Augmente l'affinité si l'endurance est à son maximum pendant un certain temps.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/corps-et-ame'}]},
#  {'name': 'Joyau feu [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'}]},
#  {'name': 'Joyau feu II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 2,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'}]},
#  {'name': 'Joyau feu III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'}]},
#  {'name': 'Joyau feu/gardien [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau feu/chamanisme [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Rage élémentaire',
#     'lvl': 1,
#     'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire'}]},
#  {'name': 'Joyau feu/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau feu/samouraï [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Samouraï',
#     'lvl': 1,
#     'description': 'Empêche votre arme de perdre son tranchant.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai'}]},
#  {'name': 'Joyau feu/kyudo [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Balistique',
#     'lvl': 1,
#     'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique'}]},
#  {'name': 'Joyau feu/premier coup [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Premier tir',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir'}]},
#  {'name': 'Joyau feu/armurier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Quatrième tir',
#     'lvl': 1,
#     'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir'}]},
#  {'name': 'Joyau feu/concentration [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Concentration',
#     'lvl': 1,
#     'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration'}]},
#  {'name': 'Joyau feu/puissance [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Puissance absolue',
#     'lvl': 1,
#     'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue'}]},
#  {'name': 'Joyau feu/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau feu/morphose [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Morphose rapide',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide'}]},
#  {'name': 'Joyau feu/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau feu/bouclier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pyromane',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'},
#    {'name': 'Ultra garde',
#     'lvl': 1,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'}]},
#  {'name': 'Joyau eau [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'}]},
#  {'name': 'Joyau eau II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 2,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'}]},
#  {'name': 'Joyau eau III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'}]},
#  {'name': 'Joyau eau/gardien [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau eau/chamanisme [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Rage élémentaire',
#     'lvl': 1,
#     'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire'}]},
#  {'name': 'Joyau eau/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau eau/samouraï [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Samouraï',
#     'lvl': 1,
#     'description': 'Empêche votre arme de perdre son tranchant.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai'}]},
#  {'name': 'Joyau eau/kyudo [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Balistique',
#     'lvl': 1,
#     'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique'}]},
#  {'name': 'Joyau eau/premier coup [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Premier tir',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir'}]},
#  {'name': 'Joyau eau/armurier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Quatrième tir',
#     'lvl': 1,
#     'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir'}]},
#  {'name': 'Joyau eau/concentration [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Concentration',
#     'lvl': 1,
#     'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration'}]},
#  {'name': 'Joyau eau/puissance [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Puissance absolue',
#     'lvl': 1,
#     'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue'}]},
#  {'name': 'Joyau eau/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau eau/morphose [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Morphose rapide',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide'}]},
#  {'name': 'Joyau eau/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau eau/bouclier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Maelstrom',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'},
#    {'name': 'Ultra garde',
#     'lvl': 1,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'}]},
#  {'name': 'Joyau glace [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'}]},
#  {'name': 'Joyau glace II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 2,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'}]},
#  {'name': 'Joyau glace III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'}]},
#  {'name': 'Joyau glace/gardien [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau glace/chamanisme [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Rage élémentaire',
#     'lvl': 1,
#     'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire'}]},
#  {'name': 'Joyau glace/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau glace/samouraï [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Samouraï',
#     'lvl': 1,
#     'description': 'Empêche votre arme de perdre son tranchant.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai'}]},
#  {'name': 'Joyau glace/kyudo [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Balistique',
#     'lvl': 1,
#     'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique'}]},
#  {'name': 'Joyau glace/premier coup [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Premier tir',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir'}]},
#  {'name': 'Joyau glace/armurier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Quatrième tir',
#     'lvl': 1,
#     'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir'}]},
#  {'name': 'Joyau glace/concentration [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Concentration',
#     'lvl': 1,
#     'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration'}]},
#  {'name': 'Joyau glace/puissance [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Puissance absolue',
#     'lvl': 1,
#     'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue'}]},
#  {'name': 'Joyau glace/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau glace/morphose [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Morphose rapide',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide'}]},
#  {'name': 'Joyau glace/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau glace/bouclier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Blizzard',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'},
#    {'name': 'Ultra garde',
#     'lvl': 1,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'}]},
#  {'name': 'Joyau foudre [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'}]},
#  {'name': 'Joyau foudre II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 2,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'}]},
#  {'name': 'Joyau foudre III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'}]},
#  {'name': 'Joyau foudre/gardien [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau foudre/chamanisme [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Rage élémentaire',
#     'lvl': 1,
#     'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire'}]},
#  {'name': 'Joyau foudre/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau foudre/samouraï [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Samouraï',
#     'lvl': 1,
#     'description': 'Empêche votre arme de perdre son tranchant.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai'}]},
#  {'name': 'Joyau foudre/kyudo [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Balistique',
#     'lvl': 1,
#     'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique'}]},
#  {'name': 'Joyau foudre/premier coup [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Premier tir',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir'}]},
#  {'name': 'Joyau foudre/armurier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Quatrième tir',
#     'lvl': 1,
#     'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir'}]},
#  {'name': 'Joyau foudre/concentration [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Concentration',
#     'lvl': 1,
#     'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration'}]},
#  {'name': 'Joyau foudre/puissance [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Puissance absolue',
#     'lvl': 1,
#     'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue'}]},
#  {'name': 'Joyau foudre/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau foudre/morphose [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Morphose rapide',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide'}]},
#  {'name': 'Joyau foudre/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau foudre/bouclier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Feu du ciel',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'},
#    {'name': 'Ultra garde',
#     'lvl': 1,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'}]},
#  {'name': 'Joyau dracocide [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'}]},
#  {'name': 'Joyau dracocide II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 2,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'}]},
#  {'name': 'Joyau dracocide III [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'}]},
#  {'name': 'Joyau dracocide/gardien [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Garde offensive',
#     'lvl': 1,
#     'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive'}]},
#  {'name': 'Joyau dracocide/chamanisme [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Rage élémentaire',
#     'lvl': 1,
#     'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire'}]},
#  {'name': 'Joyau dracocide/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau dracocide/samouraï [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Samouraï',
#     'lvl': 1,
#     'description': 'Empêche votre arme de perdre son tranchant.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai'}]},
#  {'name': 'Joyau dracocide/kyudo [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Balistique',
#     'lvl': 1,
#     'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique'}]},
#  {'name': 'Joyau dracocide/premier coup [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Premier tir',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir'}]},
#  {'name': 'Joyau dracocide/armurier [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Quatrième tir',
#     'lvl': 1,
#     'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir'}]},
#  {'name': 'Joyau dracocide/concentration [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Concentration',
#     'lvl': 1,
#     'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration'}]},
#  {'name': 'Joyau dracocide/puissance [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Puissance absolue',
#     'lvl': 1,
#     'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue'}]},
#  {'name': 'Joyau dracocide/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau dracocide/morphose [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Morphose rapide',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide'}]},
#  {'name': 'Joyau dracocide/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Pourfendeur de dragon',
#     'lvl': 3,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau dracocide/bouclier [3]',
#   'jewel_lvl': 3,
# ...
#    {'name': 'Pyromane',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane'}]},
#  {'name': 'Joyau bouclier/eau [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Maelstrom',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom'}]},
#  {'name': 'Joyau bouclier/glace [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Blizzard',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard'}]},
#  {'name': 'Joyau bouclier/foudre [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Feu du ciel',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel'}]},
#  {'name': 'Joyau bouclier/dracocide [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Pourfendeur de dragon',
#     'lvl': 1,
#     'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon'}]},
#  {'name': 'Joyau bouclier/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau bouclier/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Ultra garde',
#     'lvl': 3,
#     'description': 'Permet de parer des attaques normalement imparables.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau rengainage [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Rengainage éclair',
#     'lvl': 1,
#     'description': 'Augmente la vitesse de rengainage.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/rengainage-eclair'}]},
#  {'name': 'Joyau antivent [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Pare-vent',
#     'lvl': 1,
#     'description': 'Confère une résistance aux bourrasques.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pare-vent'}]},
#  {'name': 'Joyau antiséisme [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Sismologie',
#     'lvl': 1,
#     'description': 'Confère une résistance aux secousses.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/sismologie'}]},
#  {'name': 'Joyau inflexible [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': "Nerfs d'acier",
#     'lvl': 1,
#     'description': 'Évite les chutes et autres réactions aux dégâts mineurs.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/nerfs-dacier'}]},
#  {'name': 'Joyau intimidation [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Intimidation',
#     'lvl': 1,
#     'description': "Réduit les chances de vous faire attaquer par de petits monstres s'ils vous repèrent. Sans effet sur certains monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/intimidation'}]},
#  {'name': 'Joyau carnassier [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Carnassier',
#     'lvl': 1,
#     'description': "Augmente la vitesse de consommation de viande et d'objets.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/carnassier'}]},
#  {'name': 'Joyau franc-tireur [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 1,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'}]},
#  {'name': 'Joyau franc-tireur II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'}]},
#  {'name': 'Joyau franc-tireur/attaque [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'},
#    {'name': 'Machine de guerre',
#     'lvl': 1,
#     'description': "Augmente l'attaque.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre'}]},
#  {'name': 'Joyau franc-tireur/maître [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'},
#    {'name': "Maître d'armes",
#     'lvl': 1,
#     'description': "Augmente l'affinité.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes'}]},
#  {'name': 'Joyau franc-tireur/dégainage [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'},
#    {'name': 'Dégainage éclair',
#     'lvl': 1,
#     'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair'}]},
#  {'name': 'Joyau franc-tireur/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau franc-tireur/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Recharge chargée',
#     'lvl': 2,
#     'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': "Joyau d'Atlantis [1]",
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Mobilité eau/boue huileuse',
#     'lvl': 1,
#     'description': "Augmente la résistance contre les entraves à la mobilité dans l'eau, la boue huileuse ou les ruisseaux.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/mobilite-eauboue-huileuse'}]},
#  {'name': 'Joyau antichoc [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Antichocs',
#     'lvl': 1,
#     'description': 'Désactive les réactions aux dégâts lorsque vous touchez un allié ou inversement.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/antichocs'}]},
#  {'name': 'Joyau plongeon [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Saut de la foi',
#     'lvl': 1,
#     'description': "Permet d'esquiver de grands monstres en sautant vers eux et d'étendre la distance d'esquive.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/saut-de-la-foi'}]},
#  {'name': 'Joyau saut [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Acrobate',
#     'lvl': 1,
#     'description': 'Empêche les attaques de vous repousser pendant un saut.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/acrobate'}]},
#  {'name': 'Joyau grimpeur [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': "Monte-en-l'air",
#     'lvl': 1,
#     'description': "Réduit la perte d'endurance lorsque vous grimpez sur des lianes.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/monte-en-lair'}]},
#  {'name': 'Joyau mousquetaire [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Un pour tous',
#     'lvl': 1,
#     'description': 'Partage les effets de certains objets avec les alliés à proximité.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/un-pour-tous'}]},
#  {'name': 'Joyau survie [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Expert en survie',
#     'lvl': 1,
#     'description': 'Réduit le délai de réutilisation des outils de survie.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/expert-en-survie'}]},
#  {'name': 'Joyau bombardier [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Bombardier',
#     'lvl': 1,
#     'description': 'Augmente les dégâts occasionnés par les objets explosifs.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/bombardier'}]},
#  {'name': 'Joyau mycologue [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Mycologue extrême',
#     'lvl': 1,
#     'description': 'Permet de digérer des champignons non comestibles pour bénéficier de leurs effets positifs.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/mycologue-extreme'}]},
#  {'name': 'Joyau chimiste [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Chimiste',
#     'lvl': 1,
#     'description': 'Augmente la durée des effets pour certains objets.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/chimiste'}]},
#  {'name': 'Joyau parasite [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Pique-assiette',
#     'lvl': 1,
#     'description': 'Octroie une chance prédéfinie de consommer une nourriture ou un breuvage gratuitement.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/pique-assiette'}]},
#  {'name': 'Joyau aiguiseur [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 1,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'}]},
#  {'name': 'Joyau aiguiseur II [2]',
#   'jewel_lvl': 2,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'}]},
#  {'name': 'Joyau aiguiseur/attaque [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': 'Machine de guerre',
#     'lvl': 1,
#     'description': "Augmente l'attaque.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre'}]},
#  {'name': 'Joyau aiguiseur/maître [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': "Maître d'armes",
#     'lvl': 1,
#     'description': "Augmente l'affinité.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes'}]},
#  {'name': 'Joyau aiguiseur/dégainage [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': 'Dégainage éclair',
#     'lvl': 1,
#     'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair'}]},
#  {'name': 'Joyau aiguiseur/artisanat [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': 'Savoir-faire',
#     'lvl': 1,
#     'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire'}]},
#  {'name': 'Joyau aiguiseur/cogneur [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': 'Cogneur',
#     'lvl': 1,
#     'description': "Permet d'étourdir plus facilement les monstres.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur'}]},
#  {'name': 'Joyau aiguiseur/paladin [3]',
#   'jewel_lvl': 3,
#   'jewel_talent_list': [{'name': 'Affûtage rapide',
#     'lvl': 2,
#     'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide'},
#    {'name': 'Paladin',
#     'lvl': 1,
#     'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin'}]},
#  {'name': 'Joyau flash [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Aveuglement',
#     'lvl': 1,
#     'description': "Améliore l'efficacité des attaques et objets flash.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/aveuglement'}]},
#  {'name': 'Joyau botaniste [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Botaniste',
#     'lvl': 1,
#     'description': "Augmente la quantité d'herbes et d'objets utilisables que vous collectez.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/botaniste'}]},
#  {'name': 'Joyau géologie [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Géologiste',
#     'lvl': 1,
#     'description': "Augmente le nombre d'objets récupérés aux points de collecte.",
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/geologiste'}]},
#  {'name': 'Joyau insectoïde [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Entomologiste',
#     'lvl': 1,
#     'description': 'Les corps des petits insectes ne sont pas détruits, ce qui vous permet de les dépecer.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/entomologiste'}]},
#  {'name': 'Joyau chasse [1]',
#   'jewel_lvl': 1,
#   'jewel_talent_list': [{'name': 'Art de la chasse',
#     'lvl': 1,
#     'description': 'Améliore la pêche, le gril et les capacités de déplacement.',
#     'href': 'https://mhwilds.kiranico.com/fr/data/skills/art-de-la-chasse'}]}]

# %%
(
    pl.DataFrame(all_jewel_data)
    #
    .write_parquet(os.path.join(repo_path, "data", "jewels.parquet"))
)

# %% [markdown]
# # Scrape talents

# %%
talents_href = "https://mhwilds.kiranico.com/fr/data/skills"
driver.get(talents_href)

# %%
# Initialize an empty list to store all talents
all_talents = []

# Get all elements with the class name "my-8", which represent talent scroll groups
talents_scroll_groups = get_elements(driver, (By.CLASS_NAME, "my-8"))

# Iterate over each scroll group
for scroll_group in talents_scroll_groups:
    # Extract the group name from the <h3> tag within the scroll group
    group_name = scroll_group.find_element(By.TAG_NAME, "h3").text

    # Find all talent elements within the scroll group, represented by <tr> tags
    talents_elements = scroll_group.find_elements(By.TAG_NAME, "tr")

    # Iterate over each talent element
    for talent_element in talents_elements:
        # Extract the name and description from the <td> tags within the talent element
        name, description = talent_element.find_elements(By.TAG_NAME, "td")

        # Get the hyperlink reference (href) from the <a> tag within the name element
        href = name.find_element(By.TAG_NAME, "a").get_attribute("href")

        # Strip any leading or trailing whitespace from the name and description
        name = name.text.strip()
        description = description.text.strip()

        # Append a dictionary with the talent details to the all_talents list
        all_talents.append(
            {
                "group": group_name,
                "name": name,
                "description": description.replace("\n", " "),
                "href": href,
            }
        )

# Return the list of all talents
all_talents

# %%
for talent in reversed(tqdm(all_talents)):
    driver.get(talent["href"])
    talent_table = get_element(driver, (By.CSS_SELECTOR, ".my-8 tbody"))

    all_levels = []
    rows = talent_table.find_elements(By.TAG_NAME, "tr")

    for row in rows:
        lvl, _, description = row.find_elements(By.TAG_NAME, "td")
        lvl = int(lvl.text.replace("Lv", ""))
        description = description.text.strip()

        all_levels.append(
            {
                "lvl": lvl,
                "description": description,
            }
        )
    talent["levels"] = all_levels
all_talents
# Out:
# 100%|██████████| 148/148 [02:34<00:00,  1.05s/it]
# [{'group': 'Weapon',
#   'name': 'Machine de guerre',
#   'description': "Augmente l'attaque.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/machine-de-guerre',
#   'levels': [{'lvl': 1, 'description': 'Attaque +3'},
#    {'lvl': 2, 'description': 'Attaque +5'},
#    {'lvl': 3, 'description': 'Attaque +7'},
#    {'lvl': 4, 'description': 'Attaque +2 % Attaque +8'},
#    {'lvl': 5, 'description': 'Attaque +4 % Attaque +9'}]},
#  {'group': 'Weapon',
#   'name': 'Garde offensive',
#   'description': "Accroît temporairement la puissance d'attaque après une garde parfaitement synchronisée.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/garde-offensive',
#   'levels': [{'lvl': 1, 'description': "Attaque +5 % lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Attaque +10 % lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Attaque +15 % lorsqu'il est actif."}]},
#  {'group': 'Weapon',
#   'name': "Maître d'armes",
#   'description': "Augmente l'affinité.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-darmes',
#   'levels': [{'lvl': 1, 'description': 'Affinité +4 %'},
#    {'lvl': 2, 'description': 'Affinité +8 %'},
#    {'lvl': 3, 'description': 'Affinité +12 %'},
#    {'lvl': 4, 'description': 'Affinité +16 %'},
#    {'lvl': 5, 'description': 'Affinité +20 %'}]},
#  {'group': 'Weapon',
#   'name': 'Berserker',
#   'description': 'Augmente les dégâts des coups critiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/berserker',
#   'levels': [{'lvl': 1, 'description': 'Dégâts des coups critiques +28 %.'},
#    {'lvl': 2, 'description': 'Dégâts des coups critiques +31 %.'},
#    {'lvl': 3, 'description': 'Dégâts des coups critiques +34 %.'},
#    {'lvl': 4, 'description': 'Dégâts des coups critiques +37 %.'},
#    {'lvl': 5, 'description': 'Dégâts des coups critiques +40 %.'}]},
#  {'group': 'Weapon',
#   'name': 'Dégainage éclair',
#   'description': "Augmente l'affinité lorsque vous exécutez des attaques dégainées (sans effet en chevauchant).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/degainage-eclair',
#   'levels': [{'lvl': 1, 'description': 'Affinité +50 %'},
#    {'lvl': 2, 'description': 'Affinité +75 %'},
#    {'lvl': 3, 'description': 'Affinité +100 %'}]},
#  {'group': 'Weapon',
#   'name': 'Pyromane',
#   'description': 'Augmente la puissance des attaques élémentaires feu. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pyromane',
#   'levels': [{'lvl': 1, 'description': 'Attaque Feu +40'},
#    {'lvl': 2, 'description': 'Attaque Feu +10 % Attaque Feu +50'},
#    {'lvl': 3, 'description': 'Attaque Feu +20 % Attaque Feu +60'}]},
#  {'group': 'Weapon',
#   'name': 'Maelstrom',
#   'description': 'Augmente la puissance des attaques élémentaires eau. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maelstrom',
#   'levels': [{'lvl': 1, 'description': 'Attaque Eau +40'},
#    {'lvl': 2, 'description': 'Attaque Eau +10 % Attaque Eau +50'},
#    {'lvl': 3, 'description': 'Attaque Eau +20 % Attaque Eau +60'}]},
#  {'group': 'Weapon',
#   'name': 'Blizzard',
#   'description': 'Augmente la puissance des attaques élémentaires glace. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/blizzard',
#   'levels': [{'lvl': 1, 'description': 'Attaque Glace +40'},
#    {'lvl': 2, 'description': 'Attaque Glace +10 % Attaque Glace +50'},
#    {'lvl': 3, 'description': 'Attaque Glace +20 % Attaque Glace +60'}]},
#  {'group': 'Weapon',
#   'name': 'Feu du ciel',
#   'description': 'Augmente la puissance des attaques élémentaires foudre. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/feu-du-ciel',
#   'levels': [{'lvl': 1, 'description': 'Attaque Foudre +40'},
#    {'lvl': 2, 'description': 'Attaque Foudre +10 % Attaque Foudre +50'},
#    {'lvl': 3, 'description': 'Attaque Foudre +20 % Attaque Foudre +60'}]},
#  {'group': 'Weapon',
#   'name': 'Pourfendeur de dragon',
#   'description': 'Augmente la puissance des attaques élémentaires draconiques. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pourfendeur-de-dragon',
#   'levels': [{'lvl': 1, 'description': 'Attaque Dragon +40'},
#    {'lvl': 2, 'description': 'Attaque Dragon +10 % Attaque Dragon +50'},
#    {'lvl': 3, 'description': 'Attaque Dragon +20 % Attaque Dragon +60'}]},
#  {'group': 'Weapon',
#   'name': 'Mort-aux-rats',
#   'description': 'Augmente la puissance des afflictions de type poison. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/mort-aux-rats',
#   'levels': [{'lvl': 1,
#     'description': 'Accumulation poison +5 % Accumulation poison +10'},
#    {'lvl': 2,
#     'description': 'Accumulation poison +10 % Accumulation poison +20'},
#    {'lvl': 3,
#     'description': 'Accumulation poison +20 % Accumulation poison +50'}]},
#  {'group': 'Weapon',
#   'name': 'Neutralisation',
#   'description': 'Augmente la puissance des afflictions de type paralysie. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/neutralisation',
#   'levels': [{'lvl': 1,
#     'description': 'Accumulation paralysie +5 % Accumulation paralysie +10'},
#    {'lvl': 2,
#     'description': 'Accumulation paralysie +10 % Accumulation paralysie +20'},
#    {'lvl': 3,
#     'description': 'Accumulation paralysie +20 % Accumulation paralysie +50'}]},
#  {'group': 'Weapon',
#   'name': 'La nuit porte conseil',
#   'description': 'Augmente la puissance des afflictions de type sommeil. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/la-nuit-porte-conseil',
#   'levels': [{'lvl': 1,
#     'description': 'Accumulation sommeil +5 % Accumulation sommeil +10'},
#    {'lvl': 2,
#     'description': 'Accumulation sommeil +10 % Accumulation sommeil +20'},
#    {'lvl': 3,
#     'description': 'Accumulation sommeil +20 % Accumulation sommeil +50'}]},
#  {'group': 'Weapon',
#   'name': 'Destruction massive',
#   'description': 'Augmente la puissance des afflictions de type explosion. Il y a une limite aux augmentations.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/destruction-massive',
#   'levels': [{'lvl': 1,
#     'description': 'Accumulation explosion +5 % Accumulation explosion +10'},
#    {'lvl': 2,
#     'description': 'Accumulation explosion +10 % Accumulation explosion +20'},
#    {'lvl': 3,
#     'description': 'Accumulation explosion +20 % Accumulation explosion +50'}]},
#  {'group': 'Weapon',
#   'name': 'Rage élémentaire',
#   'description': 'Augmente les dégâts élémentaires (feu, eau, foudre, glace, dragon) infligés par des coups critiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-elementaire',
#   'levels': [{'lvl': 1,
#     'description': "Augmente légèrement les dégâts élémentaires lorsqu'il est actif."},
#    {'lvl': 2,
#     'description': "Augmente les dégâts élémentaires lorsqu'il est actif."},
#    {'lvl': 3,
#     'description': "Augmente grandement les dégâts élémentaires lorsqu'il est actif."}]},
#  {'group': 'Weapon',
#   'name': 'Attaque perfide',
#   'description': 'Augmente les afflictions (paralysie, poison, sommeil, explosion) infligées par des coups critiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/attaque-perfide',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement les afflictions infligées par des coups critiques.'},
#    {'lvl': 2,
#     'description': 'Augmente les afflictions infligées par des coups critiques.'},
#    {'lvl': 3,
#     'description': 'Augmente grandement les afflictions infligées par des coups critiques.'}]},
#  {'group': 'Weapon',
#   'name': 'Maître de la charge',
#   'description': 'Augmente la puissance élémentaire et les afflictions des attaques chargées.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-de-la-charge',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement les dégâts élémentaires et les afflictions des attaques chargées.'},
#    {'lvl': 2,
#     'description': 'Augmente les dégâts élémentaires et les afflictions des attaques chargées.'},
#    {'lvl': 3,
#     'description': 'Augmente grandement les dégâts élémentaires et les afflictions des attaques chargées.'}]},
#  {'group': 'Weapon',
#   'name': 'Savoir-faire',
#   'description': "Augmente la jauge de tranchant de l'arme. Ne peut dépasser la limite maximum.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/savoir-faire',
#   'levels': [{'lvl': 1, 'description': 'Tranchant +10'},
#    {'lvl': 2, 'description': 'Tranchant +20'},
#    {'lvl': 3, 'description': 'Tranchant +30'},
#    {'lvl': 4, 'description': 'Tranchant +40'},
#    {'lvl': 5, 'description': 'Tranchant +50'}]},
#  {'group': 'Weapon',
#   'name': 'Samouraï',
#   'description': 'Empêche votre arme de perdre son tranchant.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/samourai',
#   'levels': [{'lvl': 1,
#     'description': "10 % de chances d'annuler la perte de tranchant."},
#    {'lvl': 2,
#     'description': "25 % de chances d'annuler la perte de tranchant."},
#    {'lvl': 3,
#     'description': "50 % de chances d'annuler la perte de tranchant."}]},
#  {'group': 'Weapon',
#   'name': 'Acier trempé',
#   'description': "Le tranchant de l'arme ne diminue pas pendant un certain temps après l'affûtage.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/acier-trempe',
#   'levels': [{'lvl': 1,
#     'description': 'Annule la perte de tranchant pendant 30 s après activation.'},
#    {'lvl': 2,
#     'description': 'Annule la perte de tranchant pendant 60 s après activation.'},
#    {'lvl': 3,
#     'description': 'Annule la perte de tranchant pendant 90 s après activation.'}]},
#  {'group': 'Weapon',
#   'name': "Œil de l'esprit",
#   'description': 'Les cibles dures ont du mal à parer vos attaques et reçoivent plus de dégâts.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/oeil-de-lesprit',
#   'levels': [{'lvl': 1,
#     'description': "50 % de chances d'empêcher vos attaques d'être parées, +10 % de dégâts sur les cibles dures."},
#    {'lvl': 2,
#     'description': "100 % de chances d'empêcher vos attaques d'être parées, +15 % de dégâts sur les cibles dures."},
#    {'lvl': 3,
#     'description': "100 % de chances d'empêcher vos attaques d'être parées, +30 % de dégâts sur les cibles dures."}]},
#  {'group': 'Weapon',
#   'name': 'Matraquage',
#   'description': "Augmente l'attaque lorsque votre arme est émoussée.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/matraquage',
#   'levels': [{'lvl': 1,
#     'description': 'Attaque +5 % lorsque la jauge de tranchant est dans le jaune ou moins.'},
#    {'lvl': 2,
#     'description': 'Attaque +10 % lorsque la jauge de tranchant est dans le jaune ou moins.'},
#    {'lvl': 3,
#     'description': 'Attaque +10 % lorsque la jauge de tranchant est dans le vert ou moins.'}]},
#  {'group': 'Weapon',
#   'name': 'Main de maître',
#   'description': 'Empêche votre arme de perdre son tranchant lors de coups critiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/main-de-maitre',
#   'levels': [{'lvl': 1,
#     'description': "80 % de chances d'annuler la perte de tranchant lorsqu'il est actif."}]},
#  {'group': 'Weapon',
#   'name': 'Tir maximum',
#   'description': "Augmente la puissance des munitions et des flèches normales, et de Tir d'hirondelle volante.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/tir-maximum',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement la puissance des munitions et flèches indiquées.'}]},
#  {'group': 'Weapon',
#   'name': 'Traque sans merci',
#   'description': "Augmente l'attaque des munitions perforantes (fusarbalète) et de Perce-dragon/Mille dragons (arc).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/traque-sans-merci',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement la puissance des munitions et flèches indiquées.'}]},
#  {'group': 'Weapon',
#   'name': 'Désigné pour mourir',
#   'description': "Augmente l'attaque des munitions à grenaille (fusarbalète) et Tir de guerre/Tir rapide (arc).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/designe-pour-mourir',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement la puissance des munitions et flèches indiquées.'}]},
#  {'group': 'Weapon',
#   'name': 'Balistique',
#   'description': 'Augmente la portée à laquelle les munitions et les flèches sont à puissance maximum.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/balistique',
#   'levels': [{'lvl': 1, 'description': 'Augmente légèrement la portée.'},
#    {'lvl': 2, 'description': 'Augmente la portée.'},
#    {'lvl': 3, 'description': 'Augmente grandement la portée.'}]},
#  {'group': 'Weapon',
#   'name': 'Tir super rapide',
#   'description': 'Tir rapide fusarbalète léger amélioré.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/tir-super-rapide',
#   'levels': [{'lvl': 1, 'description': 'Dégâts tir rapide +5 %'}]},
#  {'group': 'Weapon',
#   'name': 'Premier tir',
#   'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance des balles quand il est chargé.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/premier-tir',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente modérément la vitesse de rech. du fusarbalète et la puissance du tir si les conditions sont remplies.'},
#    {'lvl': 2,
#     'description': 'Augmente la vitesse de rechargement du fusarbalète et la puissance du tir si les conditions sont remplies.'},
#    {'lvl': 3,
#     'description': 'Augmente grandement la vitesse de rech. du fusarbalète et la puissance du tir si les conditions sont remplies.'}]},
#  {'group': 'Weapon',
#   'name': 'Quatrième tir',
#   'description': "Augmente l'affinité des munitions (fusarbalète) et fioles (arc) dès le 4e tir et l'attaque pour les 4e et 6e tirs.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/quatrieme-tir',
#   'levels': [{'lvl': 1,
#     'description': "Augmente légèrement la puissance d'attaque et l'affinité des munitions sous certaines conditions."},
#    {'lvl': 2,
#     'description': "Augmente modérément la puissance d'attaque et l'affinité des munitions sous certaines conditions."},
#    {'lvl': 3,
#     'description': "Augmente la puissance d'attaque et l'affinité des munitions sous certaines conditions."}]},
#  {'group': 'Weapon',
#   'name': 'Salve mortelle',
#   'description': 'Augmente la puissance des munitions spéciales (fusarbalète) et Perce-dragon/ Mille dragons/Munitions traçantes (arc).',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/salve-mortelle',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente modérément la puissance des munitions et flèches indiquées.'},
#    {'lvl': 2,
#     'description': 'Augmente la puissance des munitions et flèches indiquées.'}]},
#  {'group': 'Weapon',
#   'name': 'Apothicaire',
#   'description': "Permet d'utiliser des fioles de poison.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/apothicaire',
#   'levels': [{'lvl': 1,
#     'description': "Permet d'utiliser des fioles de poison."}]},
#  {'group': 'Weapon',
#   'name': 'Gibier de potence',
#   'description': "Permet d'utiliser des fioles de paralysie.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/gibier-de-potence',
#   'levels': [{'lvl': 1,
#     'description': "Permet d'utiliser des fioles de paralysie."}]},
#  {'group': 'Weapon',
#   'name': 'Marchand de sable',
#   'description': "Permet d'utiliser des fioles de sommeil.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/marchand-de-sable',
#   'levels': [{'lvl': 1,
#     'description': "Permet d'utiliser des fioles de sommeil."}]},
#  {'group': 'Weapon',
#   'name': 'Maître bombardier',
#   'description': "Permet d'utiliser des fioles explosives.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitre-bombardier',
#   'levels': [{'lvl': 1,
#     'description': "Permet d'utiliser des fioles explosives."}]},
#  {'group': 'Weapon',
#   'name': 'Pattes engourdies',
#   'description': "Permet d'utiliser des fioles de léthargie.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pattes-engourdies',
#   'levels': [{'lvl': 1,
#     'description': "Permet d'utiliser des fioles de léthargie."}]},
#  {'group': 'Weapon',
#   'name': 'Concentration',
#   'description': 'Améliore la vitesse de remplissage des armes à jauges et la vitesse de chargement des armes à charges.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/concentration',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente légèrement le taux de remplissage de la jauge et réduit le temps de charge de 5 %.'},
#    {'lvl': 2,
#     'description': 'Augmente modérément le taux de remplissage de la jauge et réduit le temps de charge de 10 %.'},
#    {'lvl': 3,
#     'description': 'Augmente le taux de remplissage de la jauge et réduit le temps de charge de 15 %.'}]},
#  {'group': 'Weapon',
#   'name': 'Puissance absolue',
#   'description': 'Les épées longues, insectoglaives, lames doubles, morpho-haches, et volto-haches restent chargés plus longtemps.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-absolue',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente modérément la durée pendant laquelle les armes sont chargées.'},
#    {'lvl': 2,
#     'description': 'Augmente la durée pendant laquelle les armes sont chargées.'},
#    {'lvl': 3,
#     'description': 'Augmente grandement la durée pendant laquelle les armes sont chargés.'}]},
#  {'group': 'Weapon',
#   'name': 'Batto-jutsu',
#   'description': "Ajoute un étourdissement aux attaques dégainées. Augmente un peu l'attaque (sans effet en chevauchant).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/batto-jutsu',
#   'levels': [{'lvl': 1,
#     'description': "Attaque +3 et légers dégâts d'étourdissement infligés par les attaques dégainées."},
#    {'lvl': 2,
#     'description': "Attaque +5 et dégâts moyens d'étourdissement infligés par les attaques dégainées."},
#    {'lvl': 3,
#     'description': "Attaque +7 et dégâts importants d'étourdissement infligés par les attaques dégainées."}]},
#  {'group': 'Weapon',
#   'name': 'Cogneur',
#   'description': "Permet d'étourdir plus facilement les monstres.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/cogneur',
#   'levels': [{'lvl': 1, 'description': 'Étourdissement +20 %'},
#    {'lvl': 2, 'description': 'Étourdissement +30 %'},
#    {'lvl': 3, 'description': 'Étourdissement +40 %'}]},
#  {'group': 'Weapon',
#   'name': "Vol d'endurance",
#   'description': "Augmente la capacité de certaines attaques à infliger l'affliction léthargie aux monstres.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/vol-dendurance',
#   'levels': [{'lvl': 1, 'description': "Drain d'endurance +20 %"},
#    {'lvl': 2, 'description': "Drain d'endurance +30 %"},
#    {'lvl': 3, 'description': "Drain d'endurance +40 %"}]},
#  {'group': 'Weapon',
#   'name': 'BOUM !',
#   'description': 'Augmente la puissance des attaques explosives : lancecanon, Feu de wyverne, fioles de choc et munitions antiblindage.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/boum',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente modérément la puissance des attaques et la vitesse du Feu de wyverne. Attaque feu du Bombardement +30.'},
#    {'lvl': 2,
#     'description': 'Augmente la puissance des attaques et la vitesse du Feu de wyverne. Attaque feu du Bombardement +60.'},
#    {'lvl': 3,
#     'description': 'Augmente grandement la puissance des attaques et la vitesse du Feu de wyverne. Attaque feu du Bombardement +90.'}]},
#  {'group': 'Weapon',
#   'name': 'Morphose rapide',
#   'description': 'Augmente la vitesse de la morphose et la puissance des morpho-haches et des volto-haches.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/morphose-rapide',
#   'levels': [{'lvl': 1, 'description': 'Vitesse +10 %'},
#    {'lvl': 2, 'description': 'Vitesse +20 % Dégâts morphose +10 %'},
#    {'lvl': 3, 'description': 'Vitesse +30 % Dégâts morphose +20 %'}]},
#  {'group': 'Weapon',
#   'name': 'Maestro',
#   'description': "Prolonge la durée des mélodies des cornes de chasse (effet perdu lorsque vous changez d'arme).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maestro',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente la durée des effets des mélodies et les chances de récupérer plus de vie avec les mélodies de soin.'},
#    {'lvl': 2,
#     'description': 'Augmente encore plus la durée des effets des mélodies.'}]},
#  {'group': 'Weapon',
#   'name': 'Surcharge',
#   'description': 'Augmente votre capacité à étourdir lorsque vous frappez un monstre avec une attaque de marteau chargée.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/surcharge',
#   'levels': [{'lvl': 1, 'description': "Active l'effet."}]},
#  {'group': 'Weapon',
#   'name': "Mort venue d'en haut",
#   'description': 'Augmente la puissance des attaques sautées.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/mort-venue-den-haut',
#   'levels': [{'lvl': 1, 'description': 'Attaques sautées +10 %'}]},
#  {'group': 'Weapon',
#   'name': 'Poison +',
#   'description': "Prolonge la durée de l'effet de votre poison sur les monstres.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/poison-plus',
#   'levels': [{'lvl': 1,
#     'description': "Prolonge la durée de l'effet de votre poison de 20 %."}]},
#  {'group': 'Weapon',
#   'name': 'Paladin',
#   'description': "Réduit les repoussements et la perte d'endurance lorsque vous bloquez.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/paladin',
#   'levels': [{'lvl': 1,
#     'description': "Diminue légèrement l'impact des attaques et réduit la perte d'endurance de 15 %."},
#    {'lvl': 2,
#     'description': "Diminue l'impact des attaques et réduit la perte d'endurance de 30 %."},
#    {'lvl': 3,
#     'description': "Diminue grandement l'impact des attaques et réduit la perte d'endurance de 50 %."}]},
#  {'group': 'Weapon',
#   'name': 'Ultra garde',
#   'description': 'Permet de parer des attaques normalement imparables.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/ultra-garde',
#   'levels': [{'lvl': 1, 'description': 'Dégâts subis -30 %'},
#    {'lvl': 2, 'description': 'Dégâts subis -50 %'},
#    {'lvl': 3, 'description': 'Dégâts subis -80 %'}]},
#  {'group': 'Weapon',
#   'name': 'Recharge chargée',
#   'description': 'Améliore le rechargement et augmente le nombre de munitions du lancecanon et de fioles de volto-hache.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/recharge-chargee',
#   'levels': [{'lvl': 1,
#     'description': 'Accélère le rechargement des obus et des fioles.'},
#    {'lvl': 2,
#     'description': 'Accélère le rechargement (obus/fioles). Capacité lancecanon +1. Volto-hache : 5 fioles (jauge jaune).'}]},
#  {'group': 'Weapon',
#   'name': 'Affûtage rapide',
#   'description': "Accélère l'affûtage d'une arme avec un aiguisoir.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/affutage-rapide',
#   'levels': [{'lvl': 1, 'description': "Réduit l'affûtage d'un cycle."},
#    {'lvl': 2, 'description': "Réduit l'affûtage de deux cycles."}]},
#  {'group': 'Equip',
#   'name': 'Vengeance',
#   'description': "Augmente l'attaque lorsque vous avez subi des dégâts temporaires (zone rouge de la jauge de vie).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/vengeance',
#   'levels': [{'lvl': 1, 'description': "Attaque +5 lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Attaque +10 lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Attaque +15 lorsqu'il est actif."},
#    {'lvl': 4, 'description': "Attaque +20 lorsqu'il est actif."},
#    {'lvl': 5, 'description': "Attaque +25 lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': "Poussée d'adrénaline",
#   'description': "Esquivez juste avant une attaque pour un bonus d'attaque temporaire.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/poussee-dadrenaline',
#   'levels': [{'lvl': 1, 'description': "Attaque +10 lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Attaque +15 lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Attaque +20 lorsqu'il est actif."},
#    {'lvl': 4, 'description': "Attaque +25 lorsqu'il est actif."},
#    {'lvl': 5, 'description': "Attaque +30 lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Performance optimale',
#   'description': "Augmente l'attaque quand votre vie est à son maximum.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/performance-optimale',
#   'levels': [{'lvl': 1, 'description': "Attaque +3 lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Attaque +6 lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Attaque +10 lorsqu'il est actif."},
#    {'lvl': 4, 'description': "Attaque +15 lorsqu'il est actif."},
#    {'lvl': 5, 'description': "Attaque +20 lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Contre-attaque',
#   'description': "Accroît temporairement la puissance d'attaque après avoir été projeté.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/contre-attaque',
#   'levels': [{'lvl': 1, 'description': "Attaque +10 lorsqu'il est actif."},
#    {'lvl': 2,
#     'description': "Attaque +15 lorsqu'il est actif. Augmente modérément la durée de l'effet."},
#    {'lvl': 3,
#     'description': "Attaque +25 lorsqu'il est actif. Augmente la durée de l'effet."}]},
#  {'group': 'Equip',
#   'name': 'Mise à mort',
#   'description': "Augmente l'affinité lorsque vous attaquez le point faible d'un monstre et ses blessures.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/mise-a-mort',
#   'levels': [{'lvl': 1,
#     'description': 'Affinité +5 % pour les attaques qui touchent un point faible et bonus parties blessées de +3 %.'},
#    {'lvl': 2,
#     'description': 'Affinité +10 % pour les attaques qui touchent un point faible et bonus parties blessées de +5 %.'},
#    {'lvl': 3,
#     'description': 'Affinité +15 % pour les attaques qui touchent un point faible et bonus parties blessées de +10 %.'},
#    {'lvl': 4,
#     'description': 'Affinité +20 % pour les attaques qui touchent un point faible et bonus parties blessées de +15 %.'},
#    {'lvl': 5,
#     'description': 'Affinité +30 % pour les attaques qui touchent un point faible et bonus parties blessées de +20 %.'}]},
#  {'group': 'Equip',
#   'name': 'Corps et âme',
#   'description': "Augmente l'affinité si l'endurance est à son maximum pendant un certain temps.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/corps-et-ame',
#   'levels': [{'lvl': 1, 'description': "Affinité +10 % lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Affinité +20 % lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Affinité +30 % lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Conversion élémentaire',
#   'description': "En subissant des dégâts élémentaires, confère temporairement des effets de l'élément dragon. (Temps de rechargement après activation.)",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/conversion-elementaire',
#   'levels': [{'lvl': 1,
#     'description': "Inflige des dégâts dragon additionnels en accumulant les dégâts élémentaires. Augmente légèrement l'attaque dragon."},
#    {'lvl': 2,
#     'description': "Augmente les dégâts draconiques additionnels et l'attaque dragon."},
#    {'lvl': 3,
#     'description': "Augmente encore plus les dégâts draconiques additionnels et augmente grandement l'attaque dragon."}]},
#  {'group': 'Equip',
#   'name': 'Bastion',
#   'description': 'Augmente la défense, ainsi que les résistances élémentaires aux niveaux supérieurs.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/bastion',
#   'levels': [{'lvl': 1, 'description': 'Défense +5'},
#    {'lvl': 2, 'description': 'Défense +10'},
#    {'lvl': 3, 'description': 'Défense +5 % Défense +10'},
#    {'lvl': 4,
#     'description': 'Défense +5 % Défense +20 Résistances élémentaires +3'},
#    {'lvl': 5,
#     'description': 'Défense +8 % Défense +20 Résistances élémentaires +3'},
#    {'lvl': 6,
#     'description': 'Défense +8 % Défense +35 Résistances élémentaires +5'},
#    {'lvl': 7,
#     'description': 'Défense +10 % Défense +35 Résistances élémentaires +5'}]},
#  {'group': 'Equip',
#   'name': 'Bénédiction',
#   'description': 'A une chance prédéfinie de réduire les dégâts que vous subissez.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/benediction',
#   'levels': [{'lvl': 1,
#     'description': "Dégâts subis -15 % lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Dégâts subis -30 % lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Dégâts subis -50 % lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Ignifuge',
#   'description': 'Augmente la protection contre les attaques élémentaires feu puis les attaques physiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/ignifuge',
#   'levels': [{'lvl': 1, 'description': 'Résistance Feu +6'},
#    {'lvl': 2, 'description': 'Résistance Feu +12'},
#    {'lvl': 3, 'description': 'Résistance Feu +20 Défense +10'}]},
#  {'group': 'Equip',
#   'name': 'Étanchéité',
#   'description': 'Augmente la protection contre les attaques élémentaires eau puis les attaques physiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/etancheite',
#   'levels': [{'lvl': 1, 'description': 'Résistance Eau +6'},
#    {'lvl': 2, 'description': 'Résistance Eau +12'},
#    {'lvl': 3, 'description': 'Résistance Eau +20 Défense +10'}]},
#  {'group': 'Equip',
#   'name': 'Paratonnerre',
#   'description': 'Augmente la protection contre les attaques élémentaires foudre puis les attaques physiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/paratonnerre',
#   'levels': [{'lvl': 1, 'description': 'Résistance Foudre +6'},
#    {'lvl': 2, 'description': 'Résistance Foudre +12'},
#    {'lvl': 3, 'description': 'Résistance Foudre +20 Défense +10'}]},
#  {'group': 'Equip',
#   'name': 'Antigel',
#   'description': 'Augmente la protection contre les attaques élémentaires glace puis les attaques physiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antigel',
#   'levels': [{'lvl': 1, 'description': 'Résistance Glace +6'},
#    {'lvl': 2, 'description': 'Résistance Glace +12'},
#    {'lvl': 3, 'description': 'Résistance Glace +20 Défense +10'}]},
#  {'group': 'Equip',
#   'name': 'Aura draconique',
#   'description': 'Augmente la protection contre les attaques élémentaires dragon puis les attaques physiques.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/aura-draconique',
#   'levels': [{'lvl': 1, 'description': 'Résistance Dragon +6'},
#    {'lvl': 2, 'description': 'Résistance Dragon +12'},
#    {'lvl': 3, 'description': 'Résistance Dragon +20 Défense +10'}]},
#  {'group': 'Equip',
#   'name': 'Toxicologie',
#   'description': "Réduit les dégâts subis en cas d'empoisonnement.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/toxicologie',
#   'levels': [{'lvl': 1,
#     'description': 'Réduit le nombre de fois que vous subissez des dégâts de poison.'},
#    {'lvl': 2,
#     'description': 'Réduit grandement le nombre de fois que vous subissez des dégâts de poison.'},
#    {'lvl': 3, 'description': 'Protège du poison.'}]},
#  {'group': 'Equip',
#   'name': 'Antiparalysie',
#   'description': 'Réduit la durée de paralysie.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antiparalysie',
#   'levels': [{'lvl': 1, 'description': 'Durée paralysie -30 %'},
#    {'lvl': 2, 'description': 'Durée paralysie -60 %'},
#    {'lvl': 3, 'description': 'Protège de la paralysie.'}]},
#  {'group': 'Equip',
#   'name': 'Insomnie',
#   'description': 'Réduit la durée de sommeil.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/insomnie',
#   'levels': [{'lvl': 1, 'description': 'Durée sommeil -30 %'},
#    {'lvl': 2, 'description': 'Durée sommeil -60 %'},
#    {'lvl': 3, 'description': 'Protège du sommeil.'}]},
#  {'group': 'Equip',
#   'name': 'Peau de fer',
#   'description': 'Confère une résistance aux effets de Défense réduite.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/peau-de-fer',
#   'levels': [{'lvl': 1,
#     'description': 'Réduit la durée des effets de Défense réduite de 50 %.'},
#    {'lvl': 2,
#     'description': 'Réduit la durée des effets de Défense réduite de 75 %.'},
#    {'lvl': 3, 'description': 'Protège des effets de Défense réduite.'}]},
#  {'group': 'Equip',
#   'name': 'Totem élémentaire',
#   'description': 'Confère une résistance à tous les fléaux élémentaires.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/totem-elementaire',
#   'levels': [{'lvl': 1, 'description': 'Durée fléaux élémentaires -50 %'},
#    {'lvl': 2, 'description': 'Durée fléaux élémentaires -75 %'},
#    {'lvl': 3, 'description': 'Annule les fléaux élémentaires.'}]},
#  {'group': 'Equip',
#   'name': "Crâne d'acier",
#   'description': "Réduit la durée d'étourdissement.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/crane-dacier',
#   'levels': [{'lvl': 1, 'description': 'Durée étourdissement -30 %'},
#    {'lvl': 2, 'description': 'Durée étourdissement -60 %.'},
#    {'lvl': 3, 'description': 'Protège des étourdissements.'}]},
#  {'group': 'Equip',
#   'name': 'Antihémorragie',
#   'description': "Confère une résistance à l'hémorragie.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antihemorragie',
#   'levels': [{'lvl': 1,
#     'description': "Réduit les dégâts subis en cas d'hémorragie."},
#    {'lvl': 2,
#     'description': "Réduit grandement les dégâts subis en cas d'hémorragie."},
#    {'lvl': 3, 'description': 'Protège des hémorragies.'}]},
#  {'group': 'Equip',
#   'name': 'Anti-immobilisation',
#   'description': "Confère une résistance à l'état Toile et au fléau-givre.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/anti-immobilisation',
#   'levels': [{'lvl': 1,
#     'description': "Permet de vous débarrasser rapidement de l'état Toile et du fléau-givre."},
#    {'lvl': 2,
#     'description': "Permet de vous débarrasser très rapidement de l'état Toile et du fléau-givre."},
#    {'lvl': 3, 'description': "Protège de l'état Toile et du fléau-givre."}]},
#  {'group': 'Equip',
#   'name': 'Antiexplosion',
#   'description': 'Confère une résistance au fléau-explosion.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antiexplosion',
#   'levels': [{'lvl': 1,
#     'description': 'Retarde et réduit les dégâts des fléaux-explosion.'},
#    {'lvl': 2,
#     'description': 'Retarde et réduit grandement les dégâts des fléaux-explosion.'},
#    {'lvl': 3, 'description': 'Protège du fléau-explosion.'}]},
#  {'group': 'Equip',
#   'name': 'Antipuanteur',
#   'description': 'Confère une résistance à la puanteur.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antipuanteur',
#   'levels': [{'lvl': 1,
#     'description': 'Réduit la durée de la puanteur de 50 %.'},
#    {'lvl': 2, 'description': 'Protège de la puanteur.'}]},
#  {'group': 'Equip',
#   'name': 'Adaptabilité',
#   'description': 'Confère une résistance aux dégâts environnementaux, comme la chaleur ou le froid.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/adaptabilite',
#   'levels': [{'lvl': 1,
#     'description': 'Annule les effets du froid et de la chaleur.'},
#    {'lvl': 2, 'description': 'Annule les dégâts environnementaux.'}]},
#  {'group': 'Equip',
#   'name': 'Cercle de vie',
#   'description': 'Augmente la quantité de vie restaurée.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/cercle-de-vie',
#   'levels': [{'lvl': 1, 'description': 'Augmente légèrement la récupération.'},
#    {'lvl': 2, 'description': 'Augmente modérément la récupération.'},
#    {'lvl': 3, 'description': 'Augmente grandement la récupération.'}]},
#  {'group': 'Equip',
#   'name': 'Halo de guérison',
#   'description': 'Augmente la vitesse de guérison des dégâts temporaires (zone rouge de la jauge de vie).',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/halo-de-guerison',
#   'levels': [{'lvl': 1,
#     'description': 'Double la vitesse de récupération des dégâts temporaires.'},
#    {'lvl': 2,
#     'description': 'Triple la vitesse de récupération des dégâts temporaires.'},
#    {'lvl': 3,
#     'description': 'Quadruple la vitesse de récupération des dégâts temporaires.'}]},
#  {'group': 'Equip',
#   'name': 'Ami de la nature',
#   'description': "Vous récupérez plus de vie en interagissant avec des éléments de l'environnement.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/ami-de-la-nature',
#   'levels': [{'lvl': 1, 'description': 'Restaure 50 points de vie.'},
#    {'lvl': 2, 'description': 'Restaure 80 points de vie.'},
#    {'lvl': 3, 'description': 'Restaure 100 points de vie.'}]},
#  {'group': 'Equip',
#   'name': 'Athlète',
#   'description': "Ralentit la perte d'endurance en cas d'esquive, de blocage, etc.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/athlete',
#   'levels': [{'lvl': 1, 'description': "Coût d'endurance fixe -10 %"},
#    {'lvl': 2, 'description': "Coût d'endurance fixe -20 %"},
#    {'lvl': 3, 'description': "Coût d'endurance fixe -30 %"},
#    {'lvl': 4, 'description': "Coût d'endurance fixe -40 %"},
#    {'lvl': 5, 'description': "Coût d'endurance fixe -50 %"}]},
#  {'group': 'Equip',
#   'name': 'Métabolisme',
#   'description': "Accélère la récupération d'endurance.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/metabolisme',
#   'levels': [{'lvl': 1,
#     'description': "Vitesse de récupération d'endurance +10 %"},
#    {'lvl': 2, 'description': "Vitesse de récupération d'endurance +30 %"},
#    {'lvl': 3, 'description': "Vitesse de récupération d'endurance +50 %."}]},
#  {'group': 'Equip',
#   'name': 'Marathonien',
#   'description': "Réduit la consommation d'endurance des actions qui en utilisent en continu (exemple : courir).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/marathonien',
#   'levels': [{'lvl': 1, 'description': "Coût d'endurance -15 %"},
#    {'lvl': 2, 'description': "Coût d'endurance -30 %"},
#    {'lvl': 3, 'description': "Coût d'endurance -50 %"}]},
#  {'group': 'Equip',
#   'name': 'Coupe-faim',
#   'description': "Réduit la perte d'endurance maximum au fil du temps.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/coupe-faim',
#   'levels': [{'lvl': 1,
#     'description': "Augmente de 50 % le délai jusqu'à la réduction de votre endurance maximum."},
#    {'lvl': 2,
#     'description': "Augmente de 100 % le délai jusqu'à la réduction de votre endurance maximum."},
#    {'lvl': 3, 'description': "Empêche la réduction de l'endurance maximum."}]},
#  {'group': 'Equip',
#   'name': 'Témérité',
#   'description': "Augmente l'attaque et l'affinité lorsque les grands monstres sont enragés.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/temerite',
#   'levels': [{'lvl': 1,
#     'description': "Attaque +4 et affinité +3 % lorsqu'il est actif."},
#    {'lvl': 2,
#     'description': "Attaque +8 et affinité +5 % lorsqu'il est actif."},
#    {'lvl': 3,
#     'description': "Attaque +12 et affinité +7 % lorsqu'il est actif."},
#    {'lvl': 4,
#     'description': "Attaque +16 et affinité +10 % lorsqu'il est actif."},
#    {'lvl': 5,
#     'description': "Attaque +20 et affinité +15 % lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Force latente',
#   'description': "Augmente temporairement l'affinité et réduit la perte d'endurance dans certaines conditions.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/force-latente',
#   'levels': [{'lvl': 1,
#     'description': "Affinité +10 % Perte d'endurance -30 % lorsqu'il est actif."},
#    {'lvl': 2,
#     'description': "Affinité +20 % Perte d'endurance -30 % lorsqu'il est actif."},
#    {'lvl': 3,
#     'description': "Affinité +30 % Perte d'endurance -50 % lorsqu'il est actif."},
#    {'lvl': 4,
#     'description': "Affinité +40 % Perte d'endurance -50 % lorsqu'il est actif."},
#    {'lvl': 5,
#     'description': "Affinité +50 % Perte d'endurance -50 % lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Héroïsme',
#   'description': "Augmente l'attaque et la défense lorsque la vie est inférieure ou égale à 35 %.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/heroisme',
#   'levels': [{'lvl': 1, 'description': "Défense +50 lorsqu'il est actif."},
#    {'lvl': 2,
#     'description': "Attaque +5 % et défense physique +50 lorsqu'il est actif."},
#    {'lvl': 3,
#     'description': "Attaque +5 % et défense physique +100 lorsqu'il est actif."},
#    {'lvl': 4,
#     'description': "Attaque +10 % et défense physique +100 lorsqu'il est actif."},
#    {'lvl': 5,
#     'description': "Attaque +30 % et bonus de défense annulés lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Vendetta',
#   'description': "Attaquez sans arrêt pour augmenter progressivement l'attaque et l'attaque élémentaire. (L'augmentation dépend de l'arme.)",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/vendetta',
#   'levels': [{'lvl': 1,
#     'description': "L'attaque et les attaques élémentaires augmentent légèrement au premier coup, et encore plus après le cinquième coup."},
#    {'lvl': 2,
#     'description': "Réussir 5 attaques d'affilée renforce modérément l'effet."},
#    {'lvl': 3,
#     'description': "Réussir 5 attaques d'affilée renforce un peu plus l'effet."},
#    {'lvl': 4,
#     'description': "Réussir 5 attaques d'affilée renforce encore plus l'effet."},
#    {'lvl': 5,
#     'description': "Réussir 5 attaques d'affilée renforce énormément l'effet."}]},
#  {'group': 'Equip',
#   'name': 'Incursion',
#   'description': "Augmente l'attaque et l'affinité contre les grands monstres empoisonnés ou paralysés.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/incursion',
#   'levels': [{'lvl': 1,
#     'description': 'Attaque +6 contre les grands monstres empoisonnés ou paralysés.'},
#    {'lvl': 2,
#     'description': 'Attaque +8 et affinité +5 % contre les grands monstres empoisonnés ou paralysés.'},
#    {'lvl': 3,
#     'description': 'Attaque +10 et affinité +10 % contre les grands monstres empoisonnés ou paralysés.'},
#    {'lvl': 4,
#     'description': 'Attaque +12 et affinité +15 % contre les grands monstres empoisonnés ou paralysés.'},
#    {'lvl': 5,
#     'description': 'Attaque +15 et affinité +20 % contre les grands monstres empoisonnés ou paralysés.'}]},
#  {'group': 'Equip',
#   'name': 'Écorcheur',
#   'description': "Facilite la création d'une blessure. Infligez assez de dégâts pour un bonus de dégâts non élémentaires.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/ecorcheur',
#   'levels': [{'lvl': 1,
#     'description': "Facilite légèrement la création d'une blessure. Inflige aussi des dégâts non élémentaires."},
#    {'lvl': 2,
#     'description': "Facilite modérément la création d'une blessure. Inflige aussi légèrement plus de dégâts non élémentaires."},
#    {'lvl': 3,
#     'description': "Facilite la création d'une blessure. Inflige aussi un peu plus de dégâts non élémentaires."},
#    {'lvl': 4,
#     'description': "Facilite grandement la création d'une blessure. Inflige aussi plus de dégâts non élémentaires."},
#    {'lvl': 5,
#     'description': "Facilite énormément la création d'une blessure. Inflige beaucoup plus de dégâts non élémentaires."}]},
#  {'group': 'Equip',
#   'name': 'Esprit Palico',
#   'description': "Augmente l'attaque et la défense du Palico.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/esprit-palico',
#   'levels': [{'lvl': 1,
#     'description': "Augmente l'attaque et la défense du Palico de 5 %."},
#    {'lvl': 2,
#     'description': "Augmente l'attaque et la défense du Palico de 10 %."},
#    {'lvl': 3,
#     'description': "Augmente l'attaque et la défense du Palico de 15 %."},
#    {'lvl': 4,
#     'description': "Augmente l'attaque et la défense du Palico de 20 %."},
#    {'lvl': 5,
#     'description': "Augmente l'attaque et la défense du Palico de 25 %."}]},
#  {'group': 'Equip',
#   'name': 'Destructeur',
#   'description': 'Facilite la destruction des parties des monstres et augmente les dégâts quand vous détruisez une blessure avec une Attaque Focus.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/destructeur',
#   'levels': [{'lvl': 1,
#     'description': 'Augmente les dégâts contre les parties et les dégâts infligés de 10 % si les conditions sont remplies.'},
#    {'lvl': 2,
#     'description': 'Augmente les dégâts contre les parties et les dégâts infligés de 20 % si les conditions sont remplies.'},
#    {'lvl': 3,
#     'description': 'Augmente les dégâts contre les parties et les dégâts infligés de 30 % si les conditions sont remplies.'}]},
#  {'group': 'Equip',
#   'name': 'Union',
#   'description': "Augmente temporairement l'attaque élémentaire et les afflictions après la fin d'un fléau ou d'un statut anormal.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/union',
#   'levels': [{'lvl': 1,
#     'description': "Lorsqu'il est actif, les dégâts élémentaires et les afflictions augmentent légèrement."},
#    {'lvl': 2,
#     'description': "Lorsqu'il est actif, les dégâts élémentaires et les afflictions augmentent."},
#    {'lvl': 3,
#     'description': "Lorsqu'il est actif, les dégâts élémentaires et les afflictions augmentent grandement."}]},
#  {'group': 'Equip',
#   'name': 'Embuscade',
#   'description': 'Augmente temporairement les dégâts infligés aux grands monstres par les attaques furtives.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/embuscade',
#   'levels': [{'lvl': 1, 'description': "Attaque +5 % lorsqu'il est actif."},
#    {'lvl': 2, 'description': "Attaque +10 % lorsqu'il est actif."},
#    {'lvl': 3, 'description': "Attaque +15 % lorsqu'il est actif."}]},
#  {'group': 'Equip',
#   'name': 'Antivirus',
#   'description': "En cas d'infection, permet de surmonter plus facilement la Furie et augmente l'affinité en guérissant.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/antivirus',
#   'levels': [{'lvl': 1,
#     'description': "Accélère légèrement la guérison après avoir contracté la Furie. Augmente ensuite l'affinité de 3 %."},
#    {'lvl': 2,
#     'description': "Accélère la guérison après avoir contracté la Furie. Augmente ensuite l'affinité de 6 %."},
#    {'lvl': 3,
#     'description': "Accélère grandement la guérison après avoir contracté la Furie. Augmente ensuite l'affinité de 15 %."}]},
#  {'group': 'Equip',
#   'name': 'Absorption élémentaire',
#   'description': 'En subissant des dégâts élémentaires, confère temporairement des effets élémentaires. (Temps de rechargement après activation.)',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/absorption-elementaire',
#   'levels': [{'lvl': 1,
#     'description': "Lorsqu'il est actif, augmente légèrement l'attaque élémentaire. Résistance à l'élément subi à l'activation : +4."},
#    {'lvl': 2,
#     'description': "Lorsqu'il est actif, augmente modérément l'attaque élémentaire. Résistance à l'élément subi à l'activation : +6"},
#    {'lvl': 3,
#     'description': "Lorsqu'il est actif, augmente l'attaque élémentaire. Résistance à l'élément subi à l'activation : +8"}]},
#  {'group': 'Equip',
#   'name': 'Auto-amélioration',
#   'description': "Augmente progressivement l'attaque et la défense pendant une quête. (N'augmente plus après 30 minutes.)",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/auto-amelioration',
#   'levels': [{'lvl': 1, 'description': "Active l'effet."}]},
#  {'group': 'Equip',
#   'name': "Fenêtre d'invulnérabilité",
#   'description': "Augmente la durée de l'invulnérabilité en cas d'esquive.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/fenetre-dinvulnerabilite',
#   'levels': [{'lvl': 1,
#     'description': "Augmente très légèrement la fenêtre d'invulnérabilité."},
#    {'lvl': 2,
#     'description': "Augmente légèrement la fenêtre d'invulnérabilité."},
#    {'lvl': 3, 'description': "Augmente la fenêtre d'invulnérabilité."},
#    {'lvl': 4,
#     'description': "Augmente grandement la fenêtre d'invulnérabilité."},
#    {'lvl': 5,
#     'description': "Augmente énormément la fenêtre d'invulnérabilité."}]},
#  {'group': 'Equip',
#   'name': 'Trompe-la-mort',
#   'description': "Augmente la distance d'esquive.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/trompe-la-mort',
#   'levels': [{'lvl': 1,
#     'description': "Augmente légèrement la distance d'esquive."},
#    {'lvl': 2, 'description': "Augmente la distance d'esquive."},
#    {'lvl': 3, 'description': "Augmente grandement la distance d'esquive."}]},
#  {'group': 'Equip',
#   'name': "Bouchon d'oreilles",
#   'description': 'Confère une résistance aux rugissements des grands monstres.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/bouchon-doreilles',
#   'levels': [{'lvl': 1,
#     'description': 'Réduit les effets des petits rugissements.'},
#    {'lvl': 2,
#     'description': 'Annule les petits rugissements et réduit les effets des grands rugissements.'},
# ...
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/mycologue-extreme',
#   'levels': [{'lvl': 1,
#     'description': 'Permet de digérer les champignons bleus et les champignons vénéneux.'},
#    {'lvl': 2,
#     'description': 'Permet également de digérer les champinitros et les champaralysies.'},
#    {'lvl': 3,
#     'description': 'Permet également de digérer les mandragores, les fléaux du diable et les champexciteurs.'}]},
#  {'group': 'Equip',
#   'name': 'Chimiste',
#   'description': 'Augmente la durée des effets pour certains objets.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/chimiste',
#   'levels': [{'lvl': 1, 'description': 'Durée +10 %'},
#    {'lvl': 2, 'description': 'Durée +25 %'},
#    {'lvl': 3, 'description': 'Durée +50 %'}]},
#  {'group': 'Equip',
#   'name': 'Pique-assiette',
#   'description': 'Octroie une chance prédéfinie de consommer une nourriture ou un breuvage gratuitement.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pique-assiette',
#   'levels': [{'lvl': 1, 'description': "Chances d'activation +10 %"},
#    {'lvl': 2, 'description': "Chances d'activation +25 %"},
#    {'lvl': 3, 'description': "Chances d'activation +45 %"}]},
#  {'group': 'Equip',
#   'name': 'Aveuglement',
#   'description': "Améliore l'efficacité des attaques et objets flash.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/aveuglement',
#   'levels': [{'lvl': 1,
#     'description': "Améliore l'efficacité des attaques et objets flash."}]},
#  {'group': 'Equip',
#   'name': 'Botaniste',
#   'description': "Augmente la quantité d'herbes et d'objets utilisables que vous collectez.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/botaniste',
#   'levels': [{'lvl': 1,
#     'description': 'Une herbe supplémentaire par collecte.'},
#    {'lvl': 2,
#     'description': 'Ajoute en plus un fruit, une noix ou une graine supplémentaire par collecte.'},
#    {'lvl': 3, 'description': 'Ajoute en plus un insecte par collecte.'},
#    {'lvl': 4, 'description': 'Ajoute en plus un champignon par collecte.'}]},
#  {'group': 'Equip',
#   'name': 'Géologiste',
#   'description': "Augmente le nombre d'objets récupérés aux points de collecte.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/geologiste',
#   'levels': [{'lvl': 1,
#     'description': 'Un objet supplémentaire obtenu depuis les carcasses.'},
#    {'lvl': 2,
#     'description': 'Ajoute en plus un objet supplémentaire en collectant des objets spéciaux.'},
#    {'lvl': 3,
#     'description': 'Ajoute en plus un objet supplémentaire depuis les gisements miniers.'}]},
#  {'group': 'Equip',
#   'name': 'Entomologiste',
#   'description': 'Les corps des petits insectes ne sont pas détruits, ce qui vous permet de les dépecer.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/entomologiste',
#   'levels': [{'lvl': 1, 'description': "Active l'effet."}]},
#  {'group': 'Equip',
#   'name': 'Art de la chasse',
#   'description': 'Améliore la pêche, le gril et les capacités de déplacement.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/art-de-la-chasse',
#   'levels': [{'lvl': 1,
#     'description': 'Améliore la pêche, la cuisson au gril et les capacités de transport.'}]},
#  {'group': 'Group',
#   'name': 'Alerte Neopteron',
#   'description': '3 → Augmente la quantité de miel obtenu aux points de collecte.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/alerte-neopteron',
#   'levels': [{'lvl': 3,
#     'description': 'Augmente la quantité de miel obtenu aux points de collecte.'}]},
#  {'group': 'Group',
#   'name': 'Camouflage Neopteron',
#   'description': '3 → Augmente la vitesse de déplacement en position accroupie. Les monstres vous repèrent moins facilement.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/camouflage-neopteron',
#   'levels': [{'lvl': 3,
#     'description': 'Augmente la vitesse de déplacement en position accroupie. Les monstres vous repèrent moins facilement.'}]},
#  {'group': 'Group',
#   'name': 'Maîtrise des écailles',
#   'description': '3 → Permet de monter et de blesser les monstres plus facilement.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/maitrise-des-ecailles',
#   'levels': [{'lvl': 3,
#     'description': 'Permet de monter et de blesser les monstres plus facilement.'}]},
#  {'group': 'Group',
#   'name': 'Écailles superposées',
#   'description': "3 → Réduit temporairement la perte d'endurance lorsque la vie est inférieure ou égale à 40 %.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/ecailles-superposees',
#   'levels': [{'lvl': 3,
#     'description': "Réduit temporairement la perte d'endurance lorsque la vie est inférieure ou égale à 40 %."}]},
#  {'group': 'Group',
#   'name': 'Cuir souple',
#   'description': '3 → Augmente la vitesse de collecte et empêche les attaques de vous repousser pendant la collecte ou le dépeçage.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/cuir-souple',
#   'levels': [{'lvl': 3,
#     'description': 'Augmente la vitesse de collecte et empêche les attaques de vous repousser pendant la collecte ou le dépeçage.'}]},
#  {'group': 'Group',
#   'name': 'Douceur du cuir',
#   'description': '3 → Augmente temporairement votre affinité pendant les glissades.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/douceur-du-cuir',
#   'levels': [{'lvl': 3,
#     'description': 'Augmente temporairement votre affinité pendant les glissades.'}]},
#  {'group': 'Group',
#   'name': 'Pelage de renforcement',
#   'description': "3 → Augmente l'attaque et la défense après un évanouissement pendant une quête. *Deux fois max.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pelage-de-renforcement',
#   'levels': [{'lvl': 3,
#     'description': "Augmente l'attaque et la défense après un évanouissement pendant une quête. *Deux fois max."}]},
#  {'group': 'Group',
#   'name': 'Pelage attrayant',
#   'description': "3 → Attire davantage l'attention d'un monstre quand vous l'attaquez.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pelage-attrayant',
#   'levels': [{'lvl': 3,
#     'description': "Attire davantage l'attention d'un monstre quand vous l'attaquez."}]},
#  {'group': 'Group',
#   'name': 'Faveur du seigneur',
#   'description': "3 → Augmente temporairement la puissance d'attaque avec les effets qui affectent les compagnons (comme les Mélodies).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/faveur-du-seigneur',
#   'levels': [{'lvl': 3,
#     'description': "Augmente temporairement la puissance d'attaque avec les effets qui affectent les compagnons (comme les Mélodies)."}]},
#  {'group': 'Group',
#   'name': 'Rage supérieure',
#   'description': "3 → Augmente l'attaque quand vous êtes victime d'une affliction.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/rage-superieure',
#   'levels': [{'lvl': 3,
#     'description': "Augmente l'attaque quand vous êtes victime d'une affliction."}]},
#  {'group': 'Group',
#   'name': 'Pouls du Gardien',
#   'description': "3 → Accélère la récupération d'endurance et de la jauge rouge près des cristaux de wylait.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pouls-du-gardien',
#   'levels': [{'lvl': 3,
#     'description': "Accélère la récupération d'endurance et de la jauge rouge près des cristaux de wylait."}]},
#  {'group': 'Group',
#   'name': 'Protection du Gardien',
#   'description': '3 → Réduit les dégâts uniques et élémentaires dans les Ruines de Wyveria.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/protection-du-gardien',
#   'levels': [{'lvl': 3,
#     'description': 'Réduit les dégâts uniques et élémentaires dans les Ruines de Wyveria.'}]},
#  {'group': 'Group',
#   'name': 'Sagesse transmise',
#   'description': '3 → Augmente les chances de trouver des points de collecte rare.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/sagesse-transmise',
#   'levels': [{'lvl': 3,
#     'description': 'Augmente les chances de trouver des points de collecte rare.'}]},
#  {'group': 'Series',
#   'name': 'Puissance du Doshaguma',
#   'description': '2 → Octroie temporairement Attaque +10 après une Neutralisation ou un Duel de force réussi. 4 → Octroie temporairement Attaque +25 après une Neutralisation ou un Duel de force réussi.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/puissance-du-doshaguma',
#   'levels': [{'lvl': 2,
#     'description': 'Octroie temporairement Attaque +10 après une Neutralisation ou un Duel de force réussi.'},
#    {'lvl': 4,
#     'description': 'Octroie temporairement Attaque +25 après une Neutralisation ou un Duel de force réussi.'}]},
#  {'group': 'Series',
#   'name': 'Éclat du Rathalos',
#   'description': "2 → Chances d'infliger des dégâts de feu supplémentaires après une attaque réussie. 4 → Augmente les dégâts de feu supplémentaires après une attaque réussie.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/eclat-du-rathalos',
#   'levels': [{'lvl': 2,
#     'description': "Chances d'infliger des dégâts de feu supplémentaires après une attaque réussie."},
#    {'lvl': 4,
#     'description': 'Augmente les dégâts de feu supplémentaires après une attaque réussie.'}]},
#  {'group': 'Series',
#   'name': 'Vigueur du Xu Wu',
#   'description': "2 → Confère temporairement +15 d'attaque après avoir consommé des objets tels que des steaks à point. 4 → Confère temporairement +25 d'attaque après avoir consommé des objets tels que des steaks à point.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/vigueur-du-xu-wu',
#   'levels': [{'lvl': 2,
#     'description': "Confère temporairement +15 d'attaque après avoir consommé des objets tels que des steaks à point."},
#    {'lvl': 4,
#     'description': "Confère temporairement +25 d'attaque après avoir consommé des objets tels que des steaks à point."}]},
#  {'group': 'Series',
#   'name': 'Protection du Gravios',
#   'description': '2 → Réduit les dégâts subis de 5 % quand votre vie est pleine. 4 → Réduit les dégâts subis de 10 % quand votre vie est pleine.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/protection-du-gravios',
#   'levels': [{'lvl': 2,
#     'description': 'Réduit les dégâts subis de 5 % quand votre vie est pleine.'},
#    {'lvl': 4,
#     'description': 'Réduit les dégâts subis de 10 % quand votre vie est pleine.'}]},
#  {'group': 'Series',
#   'name': 'Esprit du Blangonga',
#   'description': "2 → Augmente l'attaque modérément et temporairement dans la zone après Victoire ! (accru pour Palicos/Chasseurs de soutien). 4 → Augmente l'attaque temporairement dans la zone après Victoire ! (accru pour Palicos/Chasseurs de soutien).",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/esprit-du-blangonga',
#   'levels': [{'lvl': 2,
#     'description': "Augmente l'attaque modérément et temporairement dans la zone après Victoire ! (accru pour Palicos/Chasseurs de soutien)."},
#    {'lvl': 4,
#     'description': "Augmente l'attaque temporairement dans la zone après Victoire ! (accru pour Palicos/Chasseurs de soutien)."}]},
#  {'group': 'Series',
#   'name': "Pouvoir de l'Odogaron désastre",
#   'description': '2 → Augmente la durée du talent Vendetta et confère Attaque +3 quand Vendetta est actif. 4 → Augmente encore la durée du talent Vendetta et confère Attaque +10 quand Vendetta est actif.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/pouvoir-de-lodogaron-desastre',
#   'levels': [{'lvl': 2,
#     'description': 'Augmente la durée du talent Vendetta et confère Attaque +3 quand Vendetta est actif.'},
#    {'lvl': 4,
#     'description': 'Augmente encore la durée du talent Vendetta et confère Attaque +10 quand Vendetta est actif.'}]},
#  {'group': 'Series',
#   'name': "Volonté de l'Anjanath tonnerre",
#   'description': "2 → Confère une jauge d'endurance supplémentaire. 4 → Confère une grande jauge d'endurance supplémentaire.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/volonte-de-lanjanath-tonnerre',
#   'levels': [{'lvl': 2,
#     'description': "Confère une jauge d'endurance supplémentaire."},
#    {'lvl': 4,
#     'description': "Confère une grande jauge d'endurance supplémentaire."}]},
#  {'group': 'Series',
#   'name': "Couverture de l'Uth Duna",
#   'description': '2 → Augmente temporairement la défense quand vous utilisez un outil de survie. 4 → Augmente grandement la défense et la résistance temporairement quand vous utilisez un outil de survie.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/couverture-de-luth-duna',
#   'levels': [{'lvl': 2,
#     'description': 'Augmente temporairement la défense quand vous utilisez un outil de survie.'},
#    {'lvl': 4,
#     'description': 'Augmente grandement la défense et la résistance temporairement quand vous utilisez un outil de survie.'}]},
#  {'group': 'Series',
#   'name': 'Tension du Rey Dau',
#   'description': '2 → Augmente modérément la durée de Force latente. 4 → Augmente la durée de Force latente.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/tension-du-rey-dau',
#   'levels': [{'lvl': 2,
#     'description': 'Augmente modérément la durée de Force latente.'},
#    {'lvl': 4, 'description': 'Augmente la durée de Force latente.'}]},
#  {'group': 'Series',
#   'name': 'Mutinerie du Nu Udra',
#   'description': '2 → Inflige une quantité modérée de dégâts supplémentaires quand le talent Vengeance est actif. 4 → Inflige des dégâts supplémentaires quand le talent Vengeance est actif.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/mutinerie-du-nu-udra',
#   'levels': [{'lvl': 2,
#     'description': 'Inflige une quantité modérée de dégâts supplémentaires quand le talent Vengeance est actif.'},
#    {'lvl': 4,
#     'description': 'Inflige des dégâts supplémentaires quand le talent Vengeance est actif.'}]},
#  {'group': 'Series',
#   'name': 'Révolte du Jin Dahaad',
#   'description': "2 → Augmente l'attaque à la fin de l'état Toile, du fléau-givre, d'une immobilisation ou d'un Duel de force. 4 → Augmente grandement l'attaque à la fin de l'état Toile, du fléau-givre, d'une immobilisation ou d'un Duel de force.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/revolte-du-jin-dahaad',
#   'levels': [{'lvl': 2,
#     'description': "Augmente l'attaque à la fin de l'état Toile, du fléau-givre, d'une immobilisation ou d'un Duel de force."},
#    {'lvl': 4,
#     'description': "Augmente grandement l'attaque à la fin de l'état Toile, du fléau-givre, d'une immobilisation ou d'un Duel de force."}]},
#  {'group': 'Series',
#   'name': 'Tyrannie du Gore Magala',
#   'description': "2 → Vous inflige la Furie face aux grands monstres. 4 → Vous inflige la Furie et augmente votre attaque face aux grands monstres. Après guérison, l'attaque est encore accrue.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/tyrannie-du-gore-magala',
#   'levels': [{'lvl': 2,
#     'description': 'Vous inflige la Furie face aux grands monstres.'},
#    {'lvl': 4,
#     'description': "Vous inflige la Furie et augmente votre attaque face aux grands monstres. Après guérison, l'attaque est encore accrue."}]},
#  {'group': 'Series',
#   'name': "Appétit de l'Arkveld",
#   'description': "2 → Restaure une quantité modérée de vie tant que vous attaquez. La régénération varie selon l'arme. 4 → Restaure de la vie tant que vous attaquez. La régénération varie selon l'arme.",
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/appetit-de-larkveld',
#   'levels': [{'lvl': 2,
#     'description': "Restaure une quantité modérée de vie tant que vous attaquez. La régénération varie selon l'arme."},
#    {'lvl': 4,
#     'description': "Restaure de la vie tant que vous attaquez. La régénération varie selon l'arme."}]},
#  {'group': 'Series',
#   'name': "Vitalité de l'Arkveld Gardien",
#   'description': '2 → Restaure une quantité modérée de vie quand vous détruisez une blessure sur un grand monstre. 4 → Restaure de la vie quand vous détruisez une blessure sur un grand monstre.',
#   'href': 'https://mhwilds.kiranico.com/fr/data/skills/vitalite-de-larkveld-gardien',
#   'levels': [{'lvl': 2,
#     'description': 'Restaure une quantité modérée de vie quand vous détruisez une blessure sur un grand monstre.'},
#    {'lvl': 4,
#     'description': 'Restaure de la vie quand vous détruisez une blessure sur un grand monstre.'}]}]

# %%
(
    pl.DataFrame(all_talents)
    #
    .write_parquet(os.path.join(repo_path, "data", "talents.parquet"))
)

# %%
# Out:
# shape: (15, 9)
# ┌────────┬───────────────┬──────────────┬──────────────┬───┬─────────┬─────────┬─────────┬─────────┐
# │ piece  ┆ name          ┆ talent_name  ┆ talent_level ┆ … ┆ jewel_1 ┆ jewel_2 ┆ jewel_3 ┆ jewel_4 │
# │ ---    ┆ ---           ┆ ---          ┆ ---          ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str    ┆ str           ┆ str          ┆ i64          ┆   ┆ i64     ┆ i64     ┆ i64     ┆ i64     │
# ╞════════╪═══════════════╪══════════════╪══════════════╪═══╪═════════╪═════════╪═════════╪═════════╡
# │ Tête   ┆ Heaume        ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien       ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Torse  ┆ Cotte Arkveld ┆ Vitalité de  ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Gardien       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆               ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Bras   ┆ Avant-bras    ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien       ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Taille ┆ Tassette      ┆ Vitalité de  ┆ 1            ┆ … ┆ 2       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien       ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Jambes ┆ Grèves        ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien       ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ …      ┆ …             ┆ …            ┆ …            ┆ … ┆ …       ┆ …       ┆ …       ┆ …       │
# │ Tête   ┆ Heaume        ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 0       ┆ 1       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien β     ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Torse  ┆ Cotte Arkveld ┆ Vitalité de  ┆ 1            ┆ … ┆ 0       ┆ 0       ┆ 1       ┆ 0       │
# │        ┆ Gardien β     ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆               ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Bras   ┆ Avant-bras    ┆ Vitalité de  ┆ 1            ┆ … ┆ 3       ┆ 0       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien β     ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Taille ┆ Tassette      ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 1       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien β     ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# │ Jambes ┆ Grèves        ┆ Vitalité de  ┆ 1            ┆ … ┆ 1       ┆ 1       ┆ 0       ┆ 0       │
# │        ┆ Arkveld       ┆ l'Arkveld    ┆              ┆   ┆         ┆         ┆         ┆         │
# │        ┆ Gardien β     ┆ Gardien      ┆              ┆   ┆         ┆         ┆         ┆         │
# └────────┴───────────────┴──────────────┴──────────────┴───┴─────────┴─────────┴─────────┴─────────┘
